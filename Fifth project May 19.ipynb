# %% [markdown]
# # Project 5

# %% [markdown]
# ## Data Description:
#
#
# You are given a set of portfolio companies trading data from emerging markets including 2020 Q1-Q2-Q3-Q4 2021 Q1 stock prices. Each company stock is provided in different sheets. Each market's operating days varies based on the country of the company and the market the stocks are exchanged. Use only 2020 data and predict with 2021 Q1 data.
#
# ## Goal(s):
#
#
# Predict stock price valuations on a daily, weekly and monthly basis. Recommend BUY, HOLD, SELL decisions. Maximize capital returns, minimize losses. Ideally a loss should never happen. Minimize HOLD period.
#
#
# ## Success Metrics:
#
#
# Evaluate on the basis of capital returns. Use Bollinger Bands to measure your systems effectiveness.

# %% [markdown]
# Plan:
# 1 - Data preparation
# 2 - Exploratory Data Analysis
# 3 - Feature engineering
# 4 - Model selection
# 5 - Decision making
# <!-- Data Preparation:
#
# Combine all the different sheets into a single dataset.
# Check for any missing or null values and handle them appropriately.
# Convert the date column to a datetime format for easy manipulation.
# Extract the day, week, and month from the date column for daily, weekly, and monthly predictions.
#
# Exploratory Data Analysis (EDA):
#
# Conduct a comprehensive EDA to identify patterns, trends, and outliers in the data.
# Use visualizations such as line plots, scatter plots, histograms, and box plots to explore the data.
# Calculate basic statistics such as mean, median, standard deviation, and correlation to gain insights into the data.
#
# Feature Engineering:
#
# Create new features such as moving averages, exponential moving averages, and Bollinger Bands to help capture trends and patterns in the data.
# Use technical indicators such as Relative Strength Index (RSI), Moving Average Convergence Divergence (MACD), and Stochastic Oscillator to create additional features.
#
# Model Selection:
#
# Select appropriate models such as Linear Regression, Random Forest Regression, and Support Vector Regression (SVR) to predict the stock prices.
# Train the models using the 2020 data and test them on the 2021 Q1 data.
# Use evaluation metrics such as Mean Squared Error (MSE), Root Mean Squared Error (RMSE), and R-squared to evaluate the performance of the models.
#
# Decision Making:
#
# Use the predicted stock prices to make BUY, HOLD, or SELL decisions.
# Calculate the capital returns based on the decisions made.
# Use Bollinger Bands to measure the effectiveness of the system.
# Minimize the HOLD period by adjusting the decision-making criteria based on the performance of the system -->

# %%
#!pip install statsmodels --upgrade
#!pip install TA-Lib
#!pip install fbprophet
#!pip install pmdarima

# %%
# linear algebra
import numpy as np 

# data processing
import pandas as pd 

# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

import re
from pylab import rcParams
import statsmodels.api as sm

import talib as ta

import itertools

# Algorithms

from prophet import Prophet
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

from keras.models import Sequential
from keras.layers import Dense, LSTM


# #Cross validation
# from sklearn.model_selection import KFold, cross_val_score

# #Other
# from sklearn import metrics
# from sklearn.model_selection import train_test_split, GridSearchCV
# from sklearn.metrics import classification_report
# from sklearn.feature_selection import SelectKBest, chi2
# from sklearn.preprocessing import PolynomialFeatures
# from sklearn.preprocessing import StandardScaler
# from sklearn.metrics import accuracy_score

# #class imbalance
# from sklearn.metrics import f1_score
# from sklearn.utils import resample
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# # 1 - Data preparation

# %%
def clean_sheets(og_data, num):
    def remove_letters(val):
        if isinstance(val, str):
            num = re.findall(r"\d+\.?\d*", val)
            if len(num) > 0:
                num = float(num[0])
                if "K" in val:
                    num /= 1000
                elif "M" in val:
                    num *= 1
                return num
        return val
    data = og_data.parse(num)
    # remove the last row as it contains text
    data.drop([data.shape[0]-1], axis=0, inplace=True)
    #clean up date column
    data[["Date"]] = data[["Date"]].apply(pd.to_datetime)
    #clean up Vol column
    data['Vol.'] = data['Vol.'].apply(remove_letters)
    #make columns numeric
    data[["Price", "Open", "High", "Low", 'Vol.', "Change %"]] = data[["Price", "Open", "High", "Low", 'Vol.', "Change %"]].apply(pd.to_numeric)
    # Set the 'Date' column as the index
    data.set_index('Date', inplace=True)
    # make the Date values the index
    data = data.sort_values(by=['Date'], ascending=True)
    print(data.head())
        # Check data types of columns
    print(data.dtypes)

    # Check for missing values
    print(data.isnull().sum())
    return data

# %%
og_data = pd.ExcelFile('2020Q1Q2Q3Q4-2021Q1.xlsx')

# %%
data1 = clean_sheets(og_data, 1)
# Out:
#             Price   Open   High    Low  Vol.  Change %
# Date
# 2020-01-02  20.38  20.42  20.44  20.24  2.53    0.0030
# 2020-01-03  20.30  20.30  20.44  19.97  3.31   -0.0039
# 2020-01-06  20.08  20.34  20.34  19.97  1.94   -0.0108
# 2020-01-07  19.93  20.22  20.28  19.92  2.89   -0.0075
# 2020-01-08  19.94  19.89  19.95  19.66  2.79    0.0005
# Price       float64
# Open        float64
# High        float64
# Low         float64
# Vol.        float64
# Change %    float64
# dtype: object
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64

# %%
data1.head()
# Out:
#             Price   Open   High    Low  Vol.  Change %
# Date
# 2020-01-02  20.38  20.42  20.44  20.24  2.53    0.0030
# 2020-01-03  20.30  20.30  20.44  19.97  3.31   -0.0039
# 2020-01-06  20.08  20.34  20.34  19.97  1.94   -0.0108
# 2020-01-07  19.93  20.22  20.28  19.92  2.89   -0.0075
# 2020-01-08  19.94  19.89  19.95  19.66  2.79    0.0005

# %%
data1.tail()
# Out:
#             Price   Open   High    Low   Vol.  Change %
# Date
# 2021-03-25  20.02  20.50  20.86  20.02  15.93   -0.0148
# 2021-03-26  19.25  20.28  20.36  19.10  21.35   -0.0385
# 2021-03-29  19.10  19.24  19.67  19.10  16.56   -0.0078
# 2021-03-30  19.50  19.12  19.81  19.03  21.05    0.0209
# 2021-03-31  19.41  19.42  19.63  19.27  13.14   -0.0046

# %% [markdown]
# # 2 - Exploratory Data Analysis

# %%
def exploration(df):
    
    # Summary statistics of the data
    print(df.describe())
        # Visualize data distribution of numeric columns
    df.hist(bins=10, figsize=(15, 10))
    plt.show()

    # Visualize correlation between variables
    sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
    plt.show()

    # Explore relationships between variables using scatter plots
    sns.pairplot(df, x_vars=['Price', 'Vol.'], y_vars=['Change %'], size=5, aspect=0.8, kind='scatter')
    plt.show()

# %%
exploration(data1)
# Out:
#             Price        Open        High         Low        Vol.    Change %
# count  315.000000  315.000000  315.000000  315.000000  315.000000  315.000000
# mean    17.857397   17.879397   18.146286   17.608667   11.087810    0.000149
# std      2.891400    2.877779    2.944378    2.850359    8.029082    0.024198
# min     12.790000   12.970000   13.110000   12.380000    1.920000   -0.099400
# 25%     15.010000   15.080000   15.225000   14.840000    5.685000   -0.013350
# 50%     17.580000   17.640000   17.860000   17.450000    8.720000    0.000700
# 75%     20.130000   20.190000   20.360000   19.970000   13.830000    0.014950
# max     24.080000   24.380000   25.480000   23.480000   56.570000    0.078000
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
y = data1['Price']
y.plot(figsize=(15, 6))
plt.show()

# %%
y.index = pd.date_range(start='2020-01-02', periods=len(y), freq='D')

rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# # 3 - Feature engineering: making weekly, monthly

# %%
# Resample the data on a weekly basis and calculate the mean
data1W = data1.resample('W').mean()
# Resample the data on a monthly basis and calculate the mean
data1M = data1.resample('M').mean()

# %%
data1M
# Out:
#                 Price       Open       High        Low       Vol.  Change %
# Date
# 2020-01-31  20.540455  20.599545  20.770455  20.300455   3.695909 -0.001673
# 2020-02-29  19.474000  19.615000  19.859500  19.213500   6.034500 -0.006045
# 2020-03-31  15.055909  15.272273  15.630909  14.805455   4.165000 -0.011041
# 2020-04-30  14.692381  14.663333  14.927143  14.458095   6.980952  0.007486
# 2020-05-31  15.212941  15.210588  15.398824  15.033529   7.333529  0.003218
# 2020-06-30  17.395000  17.349545  17.593636  17.147727   7.538636  0.005132
# 2020-07-31  17.425238  17.568571  17.689524  17.301905   7.330476 -0.004957
# 2020-08-31  15.354500  15.443500  15.616500  15.101000  19.221500 -0.003800
# 2020-09-30  14.631818  14.680000  14.775909  14.507273  13.287273 -0.000591
# 2020-10-31  14.863810  14.873333  15.000952  14.713810  17.653810 -0.001571
# 2020-11-30  17.567619  17.439524  17.842857  17.136190  24.951905  0.011024
# 2020-12-31  19.483913  19.335217  19.675652  19.200435  10.160435  0.007957
# 2021-01-31  21.563000  21.592000  21.911000  21.250000  10.190500 -0.002025
# 2021-02-28  22.011000  21.977000  22.389000  21.712000  13.251500  0.003520
# 2021-03-31  22.045217  22.039130  22.548261  21.716087  14.520435 -0.004152

# %% [markdown]
# # 4 - Models

# %%
data1.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Change %'], dtype='object')

# %%
data1.head()
# Out:
#           Date  Price   Open   High    Low  Vol.  Change %
# 314 2020-01-02  20.38  20.42  20.44  20.24  2.53    0.0030
# 313 2020-01-03  20.30  20.30  20.44  19.97  3.31   -0.0039
# 312 2020-01-06  20.08  20.34  20.34  19.97  1.94   -0.0108
# 311 2020-01-07  19.93  20.22  20.28  19.92  2.89   -0.0075
# 310 2020-01-08  19.94  19.89  19.95  19.66  2.79    0.0005

# %%
print(data1.iloc[-64])
print(64/len(data1))
# Out:
# Date        2020-12-31 00:00:00
# Price                     21.12
# Open                      20.84
# High                      21.38
# Low                       20.72
# Vol.                       7.12
# Change %                 0.0086
# Name: 63, dtype: object
# 0.20317460317460317

# %% [markdown]
# ## LSTM model

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:i+look_back, 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

def model_LSTM(dataset, look_back=1):
  
    # # normalize the dataset
    scaler = MinMaxScaler(feature_range=(0, 1))
    dataset = scaler.fit_transform(dataset)
    # split into train and test sets
    train_size = int(len(dataset) * 0.8)
    test_size = len(dataset) - train_size    
    train, test = dataset[0:train_size,:], dataset[train_size-look_back:len(dataset),:]
#     print(len(train), len(test))
    # reshape into X=t and Y=t+1
    trainX, trainY = create_dataset(train, look_back)
    testX, testY = create_dataset(test, look_back)
    # reshape input to be [samples, time steps, features]
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    #print(testX)
    # # create and fit the LSTM network
    model = Sequential()
    model.add(LSTM(4, input_shape=(1, look_back)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
    # make predictions
    #trainPredict = model.predict(trainX)
    
    # Prepare input data
    inputs = trainX[-look_back:]
    #inputs = np.reshape(inputs, (inputs.shape[0], 1, inputs.shape[1]))
    # Predict next 60 values
    forecasts = []
    print(len(testY))
    for i in range(len(testY)):
        # Forecast next value
        forecast = model.predict(inputs)
        forecast = scaler.inverse_transform(forecast)[0][0]
        forecasts.append(forecast)
        new = np.append(inputs[-1:,:,1:],[[[forecast]]],axis=2)

        # Update input sequence
        inputs = np.append(inputs[1:,:,:],new,axis=0)

    # Print forecasts
    print("Next values: ", forecasts)   
#     testPredict = model.predict(testX)
    # invert predictions
    #trainPredict = scaler.inverse_transform(trainPredict)
#    print(trainPredict)
    #trainY = scaler.inverse_transform([trainY])
#     testPredict = scaler.inverse_transform(testPredict)
    testY = scaler.inverse_transform([testY])
    # calculate root mean squared error
#     trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
#     print('Train Score: %.2f RMSE' % (trainScore))
    testScore = np.sqrt(mean_squared_error(testY[0], forecasts))
    print('Test Score: %.2f RMSE' % (testScore))
    # shift train predictions for plotting
#     trainPredictPlot = np.empty_like(dataset)
#     trainPredictPlot[:, :] = np.nan
#     trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
    # shift test predictions for plotting
    testPredictPlot = np.empty_like(dataset)
    testPredictPlot[:, :] = np.nan
    forecasts = np.array(forecasts)
    forecasts = forecasts.reshape(-1, 1)
    testPredictPlot[len(train):len(dataset), :] = forecasts
    # plot baseline and predictions
    plt.plot(scaler.inverse_transform(dataset), color = 'b')
    #plt.plot(trainPredictPlot, color = 'g')
    plt.plot(testPredictPlot, color = 'r')
    plt.show()

# %%
def pre_LSTM(df):
    df = df['Price']
    data = df.values
    data = data.astype('float32')
    data = data.reshape(-1, 1)
    return data

# %% [markdown]
# ### Daily basis

# %%
model_LSTM(pre_LSTM(data1), 10)
# Out:
# Epoch 1/100
# 242/242 - 2s - loss: 0.0161 - 2s/epoch - 7ms/step
# Epoch 2/100
# 242/242 - 0s - loss: 0.0053 - 267ms/epoch - 1ms/step
# Epoch 3/100
# 242/242 - 0s - loss: 0.0046 - 231ms/epoch - 953us/step
# Epoch 4/100
# 242/242 - 0s - loss: 0.0040 - 246ms/epoch - 1ms/step
# Epoch 5/100
# 242/242 - 0s - loss: 0.0035 - 284ms/epoch - 1ms/step
# Epoch 6/100
# 242/242 - 0s - loss: 0.0032 - 261ms/epoch - 1ms/step
# Epoch 7/100
# 242/242 - 0s - loss: 0.0029 - 239ms/epoch - 986us/step
# Epoch 8/100
# 242/242 - 0s - loss: 0.0028 - 247ms/epoch - 1ms/step
# Epoch 9/100
# 242/242 - 0s - loss: 0.0027 - 226ms/epoch - 932us/step
# Epoch 10/100
# 242/242 - 0s - loss: 0.0026 - 234ms/epoch - 967us/step
# Epoch 11/100
# 242/242 - 0s - loss: 0.0025 - 244ms/epoch - 1ms/step
# Epoch 12/100
# 242/242 - 0s - loss: 0.0026 - 231ms/epoch - 956us/step
# Epoch 13/100
# 242/242 - 0s - loss: 0.0024 - 263ms/epoch - 1ms/step
# Epoch 14/100
# 242/242 - 0s - loss: 0.0025 - 236ms/epoch - 973us/step
# Epoch 15/100
# 242/242 - 0s - loss: 0.0023 - 231ms/epoch - 955us/step
# Epoch 16/100
# 242/242 - 0s - loss: 0.0022 - 234ms/epoch - 967us/step
# Epoch 17/100
# 242/242 - 0s - loss: 0.0022 - 227ms/epoch - 936us/step
# Epoch 18/100
# 242/242 - 0s - loss: 0.0021 - 231ms/epoch - 955us/step
# Epoch 19/100
# 242/242 - 0s - loss: 0.0021 - 230ms/epoch - 950us/step
# Epoch 20/100
# 242/242 - 0s - loss: 0.0021 - 226ms/epoch - 933us/step
# Epoch 21/100
# 242/242 - 0s - loss: 0.0020 - 246ms/epoch - 1ms/step
# Epoch 22/100
# 242/242 - 0s - loss: 0.0020 - 231ms/epoch - 954us/step
# Epoch 23/100
# 242/242 - 0s - loss: 0.0019 - 220ms/epoch - 908us/step
# Epoch 24/100
# 242/242 - 0s - loss: 0.0019 - 224ms/epoch - 926us/step
# Epoch 25/100
# 242/242 - 0s - loss: 0.0018 - 244ms/epoch - 1ms/step
# Epoch 26/100
# 242/242 - 0s - loss: 0.0018 - 242ms/epoch - 1ms/step
# Epoch 27/100
# 242/242 - 0s - loss: 0.0018 - 228ms/epoch - 942us/step
# Epoch 28/100
# 242/242 - 0s - loss: 0.0018 - 235ms/epoch - 969us/step
# Epoch 29/100
# 242/242 - 0s - loss: 0.0018 - 225ms/epoch - 930us/step
# Epoch 30/100
# 242/242 - 0s - loss: 0.0017 - 233ms/epoch - 964us/step
# Epoch 31/100
# 242/242 - 0s - loss: 0.0017 - 220ms/epoch - 910us/step
# Epoch 32/100
# 242/242 - 0s - loss: 0.0018 - 222ms/epoch - 918us/step
# Epoch 33/100
# 242/242 - 0s - loss: 0.0017 - 227ms/epoch - 937us/step
# Epoch 34/100
# 242/242 - 0s - loss: 0.0017 - 222ms/epoch - 917us/step
# Epoch 35/100
# 242/242 - 0s - loss: 0.0017 - 232ms/epoch - 960us/step
# Epoch 36/100
# 242/242 - 0s - loss: 0.0016 - 228ms/epoch - 942us/step
# Epoch 37/100
# 242/242 - 0s - loss: 0.0018 - 227ms/epoch - 937us/step
# Epoch 38/100
# 242/242 - 0s - loss: 0.0017 - 254ms/epoch - 1ms/step
# Epoch 39/100
# 242/242 - 0s - loss: 0.0016 - 244ms/epoch - 1ms/step
# Epoch 40/100
# 242/242 - 0s - loss: 0.0016 - 217ms/epoch - 898us/step
# Epoch 41/100
# 242/242 - 0s - loss: 0.0015 - 221ms/epoch - 915us/step
# Epoch 42/100
# 242/242 - 0s - loss: 0.0017 - 232ms/epoch - 961us/step
# Epoch 43/100
# 242/242 - 0s - loss: 0.0016 - 224ms/epoch - 925us/step
# Epoch 44/100
# 242/242 - 0s - loss: 0.0016 - 222ms/epoch - 917us/step
# Epoch 45/100
# 242/242 - 0s - loss: 0.0016 - 234ms/epoch - 968us/step
# Epoch 46/100
# 242/242 - 0s - loss: 0.0016 - 224ms/epoch - 927us/step
# Epoch 47/100
# 242/242 - 0s - loss: 0.0017 - 229ms/epoch - 947us/step
# Epoch 48/100
# 242/242 - 0s - loss: 0.0016 - 224ms/epoch - 924us/step
# Epoch 49/100
# 242/242 - 0s - loss: 0.0015 - 219ms/epoch - 906us/step
# Epoch 50/100
# 242/242 - 0s - loss: 0.0015 - 222ms/epoch - 919us/step
# Epoch 51/100
# 242/242 - 0s - loss: 0.0016 - 280ms/epoch - 1ms/step
# Epoch 52/100
# 242/242 - 0s - loss: 0.0016 - 215ms/epoch - 888us/step
# Epoch 53/100
# 242/242 - 0s - loss: 0.0014 - 229ms/epoch - 946us/step
# Epoch 54/100
# 242/242 - 0s - loss: 0.0015 - 254ms/epoch - 1ms/step
# Epoch 55/100
# 242/242 - 0s - loss: 0.0015 - 220ms/epoch - 908us/step
# Epoch 56/100
# 242/242 - 0s - loss: 0.0015 - 227ms/epoch - 938us/step
# Epoch 57/100
# 242/242 - 0s - loss: 0.0014 - 225ms/epoch - 928us/step
# Epoch 58/100
# 242/242 - 0s - loss: 0.0015 - 215ms/epoch - 888us/step
# Epoch 59/100
# 242/242 - 0s - loss: 0.0014 - 217ms/epoch - 896us/step
# Epoch 60/100
# 242/242 - 0s - loss: 0.0015 - 213ms/epoch - 881us/step
# Epoch 61/100
# 242/242 - 0s - loss: 0.0015 - 219ms/epoch - 906us/step
# Epoch 62/100
# 242/242 - 0s - loss: 0.0015 - 230ms/epoch - 952us/step
# Epoch 63/100
# 242/242 - 0s - loss: 0.0015 - 227ms/epoch - 939us/step
# Epoch 64/100
# 242/242 - 0s - loss: 0.0014 - 217ms/epoch - 897us/step
# Epoch 65/100
# 242/242 - 0s - loss: 0.0014 - 231ms/epoch - 956us/step
# Epoch 66/100
# 242/242 - 0s - loss: 0.0014 - 219ms/epoch - 903us/step
# Epoch 67/100
# 242/242 - 0s - loss: 0.0014 - 212ms/epoch - 875us/step
# Epoch 68/100
# 242/242 - 0s - loss: 0.0014 - 237ms/epoch - 980us/step
# Epoch 69/100
# 242/242 - 0s - loss: 0.0014 - 221ms/epoch - 915us/step
# Epoch 70/100
# 242/242 - 0s - loss: 0.0015 - 223ms/epoch - 920us/step
# Epoch 71/100
# 242/242 - 0s - loss: 0.0014 - 221ms/epoch - 914us/step
# Epoch 72/100
# 242/242 - 0s - loss: 0.0014 - 223ms/epoch - 923us/step
# Epoch 73/100
# 242/242 - 0s - loss: 0.0014 - 236ms/epoch - 976us/step
# Epoch 74/100
# 242/242 - 0s - loss: 0.0014 - 244ms/epoch - 1ms/step
# Epoch 75/100
# 242/242 - 0s - loss: 0.0014 - 238ms/epoch - 982us/step
# Epoch 76/100
# 242/242 - 0s - loss: 0.0015 - 248ms/epoch - 1ms/step
# Epoch 77/100
# 242/242 - 0s - loss: 0.0014 - 253ms/epoch - 1ms/step
# Epoch 78/100
# 242/242 - 0s - loss: 0.0014 - 245ms/epoch - 1ms/step
# Epoch 79/100
# 242/242 - 0s - loss: 0.0014 - 221ms/epoch - 911us/step
# Epoch 80/100
# 242/242 - 0s - loss: 0.0014 - 224ms/epoch - 925us/step
# Epoch 81/100
# 242/242 - 0s - loss: 0.0014 - 227ms/epoch - 940us/step
# Epoch 82/100
# 242/242 - 0s - loss: 0.0015 - 234ms/epoch - 967us/step
# Epoch 83/100
# 242/242 - 0s - loss: 0.0014 - 212ms/epoch - 878us/step
# Epoch 84/100
# 242/242 - 0s - loss: 0.0013 - 237ms/epoch - 980us/step
# Epoch 85/100
# 242/242 - 0s - loss: 0.0015 - 223ms/epoch - 922us/step
# Epoch 86/100
# 242/242 - 0s - loss: 0.0014 - 215ms/epoch - 889us/step
# Epoch 87/100
# 242/242 - 0s - loss: 0.0014 - 224ms/epoch - 925us/step
# Epoch 88/100
# 242/242 - 0s - loss: 0.0014 - 220ms/epoch - 911us/step
# Epoch 89/100
# 242/242 - 0s - loss: 0.0015 - 223ms/epoch - 920us/step
# Epoch 90/100
# 242/242 - 0s - loss: 0.0014 - 239ms/epoch - 987us/step
# Epoch 91/100
# 242/242 - 0s - loss: 0.0014 - 294ms/epoch - 1ms/step
# Epoch 92/100
# 242/242 - 0s - loss: 0.0014 - 215ms/epoch - 888us/step
# Epoch 93/100
# 242/242 - 0s - loss: 0.0014 - 226ms/epoch - 934us/step
# Epoch 94/100
# 242/242 - 0s - loss: 0.0013 - 220ms/epoch - 911us/step
# Epoch 95/100
# 242/242 - 0s - loss: 0.0013 - 238ms/epoch - 984us/step
# Epoch 96/100
# 242/242 - 0s - loss: 0.0014 - 220ms/epoch - 911us/step
# Epoch 97/100
# 242/242 - 0s - loss: 0.0014 - 222ms/epoch - 919us/step
# Epoch 98/100
# 242/242 - 0s - loss: 0.0015 - 216ms/epoch - 891us/step
# Epoch 99/100
# 242/242 - 0s - loss: 0.0013 - 228ms/epoch - 941us/step
# Epoch 100/100
# 242/242 - 0s - loss: 0.0015 - 225ms/epoch - 930us/step
# 63
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# Next values:  [19.878399, 19.907274, 19.39111, 19.519209, 19.67066, 19.726297, 19.76048, 19.905142, 20.403368, 20.700615, 42.682507, 37.624672, 26.69026, 28.794035, 28.882195, 28.640898, 27.954279, 29.079517, 33.19664, 32.7058, 36.540184, 37.627945, 26.035, 26.57634, 37.594437, 31.951233, 29.000547, 37.29095, 33.48516, 29.803164, 32.82163, 36.911907, 33.229706, 29.059875, 36.390152, 36.76699, 28.981627, 33.70673, 37.587875, 28.994564, 29.506714, 37.564453, 31.292927, 29.01923, 35.954475, 37.0328, 29.126654, 29.226027, 37.51123, 31.06741, 28.981165, 37.07529, 36.946568, 28.978443, 33.531654, 37.551548, 29.102182, 29.037516, 37.503162, 34.231857, 28.981758, 35.575687, 37.518208]
# Test Score: 10.72 RMSE

# %%
model_LSTM(pre_LSTM(data1), 30)
# Out:
# Epoch 1/100
# 222/222 - 1s - loss: 0.0250 - 1s/epoch - 7ms/step
# Epoch 2/100
# 222/222 - 0s - loss: 0.0087 - 197ms/epoch - 885us/step
# Epoch 3/100
# 222/222 - 0s - loss: 0.0041 - 202ms/epoch - 908us/step
# Epoch 4/100
# 222/222 - 0s - loss: 0.0031 - 216ms/epoch - 971us/step
# Epoch 5/100
# 222/222 - 0s - loss: 0.0025 - 229ms/epoch - 1ms/step
# Epoch 6/100
# 222/222 - 0s - loss: 0.0023 - 220ms/epoch - 990us/step
# Epoch 7/100
# 222/222 - 0s - loss: 0.0022 - 229ms/epoch - 1ms/step
# Epoch 8/100
# 222/222 - 0s - loss: 0.0021 - 210ms/epoch - 945us/step
# Epoch 9/100
# 222/222 - 0s - loss: 0.0021 - 199ms/epoch - 899us/step
# Epoch 10/100
# 222/222 - 0s - loss: 0.0019 - 205ms/epoch - 925us/step
# Epoch 11/100
# 222/222 - 0s - loss: 0.0022 - 221ms/epoch - 996us/step
# Epoch 12/100
# 222/222 - 0s - loss: 0.0023 - 216ms/epoch - 974us/step
# Epoch 13/100
# 222/222 - 0s - loss: 0.0017 - 196ms/epoch - 883us/step
# Epoch 14/100
# 222/222 - 0s - loss: 0.0019 - 198ms/epoch - 893us/step
# Epoch 15/100
# 222/222 - 0s - loss: 0.0019 - 193ms/epoch - 870us/step
# Epoch 16/100
# 222/222 - 0s - loss: 0.0018 - 198ms/epoch - 892us/step
# Epoch 17/100
# 222/222 - 0s - loss: 0.0018 - 211ms/epoch - 952us/step
# Epoch 18/100
# 222/222 - 0s - loss: 0.0016 - 223ms/epoch - 1ms/step
# Epoch 19/100
# 222/222 - 0s - loss: 0.0019 - 286ms/epoch - 1ms/step
# Epoch 20/100
# 222/222 - 0s - loss: 0.0016 - 257ms/epoch - 1ms/step
# Epoch 21/100
# 222/222 - 0s - loss: 0.0018 - 240ms/epoch - 1ms/step
# Epoch 22/100
# 222/222 - 0s - loss: 0.0018 - 251ms/epoch - 1ms/step
# Epoch 23/100
# 222/222 - 0s - loss: 0.0016 - 304ms/epoch - 1ms/step
# Epoch 24/100
# 222/222 - 0s - loss: 0.0017 - 337ms/epoch - 2ms/step
# Epoch 25/100
# 222/222 - 0s - loss: 0.0017 - 343ms/epoch - 2ms/step
# Epoch 26/100
# 222/222 - 1s - loss: 0.0017 - 521ms/epoch - 2ms/step
# Epoch 27/100
# 222/222 - 1s - loss: 0.0016 - 506ms/epoch - 2ms/step
# Epoch 28/100
# 222/222 - 0s - loss: 0.0020 - 328ms/epoch - 1ms/step
# Epoch 29/100
# 222/222 - 0s - loss: 0.0015 - 277ms/epoch - 1ms/step
# Epoch 30/100
# 222/222 - 0s - loss: 0.0016 - 293ms/epoch - 1ms/step
# Epoch 31/100
# 222/222 - 1s - loss: 0.0017 - 780ms/epoch - 4ms/step
# Epoch 32/100
# 222/222 - 1s - loss: 0.0015 - 705ms/epoch - 3ms/step
# Epoch 33/100
# 222/222 - 0s - loss: 0.0015 - 280ms/epoch - 1ms/step
# Epoch 34/100
# 222/222 - 0s - loss: 0.0015 - 241ms/epoch - 1ms/step
# Epoch 35/100
# 222/222 - 1s - loss: 0.0015 - 802ms/epoch - 4ms/step
# Epoch 36/100
# 222/222 - 1s - loss: 0.0016 - 684ms/epoch - 3ms/step
# Epoch 37/100
# 222/222 - 0s - loss: 0.0017 - 300ms/epoch - 1ms/step
# Epoch 38/100
# 222/222 - 0s - loss: 0.0016 - 254ms/epoch - 1ms/step
# Epoch 39/100
# 222/222 - 1s - loss: 0.0015 - 1s/epoch - 5ms/step
# Epoch 40/100
# 222/222 - 1s - loss: 0.0015 - 710ms/epoch - 3ms/step
# Epoch 41/100
# 222/222 - 0s - loss: 0.0015 - 264ms/epoch - 1ms/step
# Epoch 42/100
# 222/222 - 0s - loss: 0.0015 - 274ms/epoch - 1ms/step
# Epoch 43/100
# 222/222 - 0s - loss: 0.0016 - 301ms/epoch - 1ms/step
# Epoch 44/100
# 222/222 - 0s - loss: 0.0015 - 326ms/epoch - 1ms/step
# Epoch 45/100
# 222/222 - 0s - loss: 0.0015 - 291ms/epoch - 1ms/step
# Epoch 46/100
# 222/222 - 0s - loss: 0.0015 - 284ms/epoch - 1ms/step
# Epoch 47/100
# 222/222 - 0s - loss: 0.0015 - 314ms/epoch - 1ms/step
# Epoch 48/100
# 222/222 - 0s - loss: 0.0015 - 305ms/epoch - 1ms/step
# Epoch 49/100
# 222/222 - 0s - loss: 0.0016 - 284ms/epoch - 1ms/step
# Epoch 50/100
# 222/222 - 0s - loss: 0.0015 - 298ms/epoch - 1ms/step
# Epoch 51/100
# 222/222 - 0s - loss: 0.0015 - 275ms/epoch - 1ms/step
# Epoch 52/100
# 222/222 - 0s - loss: 0.0015 - 235ms/epoch - 1ms/step
# Epoch 53/100
# 222/222 - 0s - loss: 0.0016 - 350ms/epoch - 2ms/step
# Epoch 54/100
# 222/222 - 1s - loss: 0.0016 - 864ms/epoch - 4ms/step
# Epoch 55/100
# 222/222 - 0s - loss: 0.0014 - 213ms/epoch - 959us/step
# Epoch 56/100
# 222/222 - 0s - loss: 0.0014 - 208ms/epoch - 936us/step
# Epoch 57/100
# 222/222 - 0s - loss: 0.0014 - 267ms/epoch - 1ms/step
# Epoch 58/100
# 222/222 - 0s - loss: 0.0014 - 255ms/epoch - 1ms/step
# Epoch 59/100
# 222/222 - 0s - loss: 0.0014 - 228ms/epoch - 1ms/step
# Epoch 60/100
# 222/222 - 0s - loss: 0.0014 - 224ms/epoch - 1ms/step
# Epoch 61/100
# 222/222 - 0s - loss: 0.0015 - 237ms/epoch - 1ms/step
# Epoch 62/100
# 222/222 - 0s - loss: 0.0014 - 243ms/epoch - 1ms/step
# Epoch 63/100
# 222/222 - 0s - loss: 0.0014 - 231ms/epoch - 1ms/step
# Epoch 64/100
# 222/222 - 0s - loss: 0.0014 - 251ms/epoch - 1ms/step
# Epoch 65/100
# 222/222 - 0s - loss: 0.0014 - 251ms/epoch - 1ms/step
# Epoch 66/100
# 222/222 - 0s - loss: 0.0014 - 250ms/epoch - 1ms/step
# Epoch 67/100
# 222/222 - 0s - loss: 0.0014 - 277ms/epoch - 1ms/step
# Epoch 68/100
# 222/222 - 0s - loss: 0.0014 - 281ms/epoch - 1ms/step
# Epoch 69/100
# 222/222 - 0s - loss: 0.0014 - 273ms/epoch - 1ms/step
# Epoch 70/100
# 222/222 - 0s - loss: 0.0013 - 270ms/epoch - 1ms/step
# Epoch 71/100
# 222/222 - 0s - loss: 0.0013 - 270ms/epoch - 1ms/step
# Epoch 72/100
# 222/222 - 0s - loss: 0.0014 - 266ms/epoch - 1ms/step
# Epoch 73/100
# 222/222 - 0s - loss: 0.0014 - 268ms/epoch - 1ms/step
# Epoch 74/100
# 222/222 - 0s - loss: 0.0014 - 256ms/epoch - 1ms/step
# Epoch 75/100
# 222/222 - 0s - loss: 0.0015 - 249ms/epoch - 1ms/step
# Epoch 76/100
# 222/222 - 0s - loss: 0.0015 - 258ms/epoch - 1ms/step
# Epoch 77/100
# 222/222 - 0s - loss: 0.0014 - 255ms/epoch - 1ms/step
# Epoch 78/100
# 222/222 - 0s - loss: 0.0015 - 249ms/epoch - 1ms/step
# Epoch 79/100
# 222/222 - 0s - loss: 0.0013 - 263ms/epoch - 1ms/step
# Epoch 80/100
# 222/222 - 0s - loss: 0.0014 - 261ms/epoch - 1ms/step
# Epoch 81/100
# 222/222 - 0s - loss: 0.0013 - 220ms/epoch - 991us/step
# Epoch 82/100
# 222/222 - 0s - loss: 0.0012 - 219ms/epoch - 986us/step
# Epoch 83/100
# 222/222 - 0s - loss: 0.0013 - 218ms/epoch - 982us/step
# Epoch 84/100
# 222/222 - 0s - loss: 0.0013 - 209ms/epoch - 943us/step
# Epoch 85/100
# 222/222 - 0s - loss: 0.0013 - 221ms/epoch - 996us/step
# Epoch 86/100
# 222/222 - 0s - loss: 0.0013 - 219ms/epoch - 986us/step
# Epoch 87/100
# 222/222 - 0s - loss: 0.0013 - 212ms/epoch - 954us/step
# Epoch 88/100
# 222/222 - 0s - loss: 0.0012 - 205ms/epoch - 922us/step
# Epoch 89/100
# 222/222 - 0s - loss: 0.0013 - 203ms/epoch - 914us/step
# Epoch 90/100
# 222/222 - 0s - loss: 0.0012 - 211ms/epoch - 951us/step
# Epoch 91/100
# 222/222 - 0s - loss: 0.0013 - 205ms/epoch - 924us/step
# Epoch 92/100
# 222/222 - 0s - loss: 0.0014 - 206ms/epoch - 928us/step
# Epoch 93/100
# 222/222 - 0s - loss: 0.0013 - 212ms/epoch - 955us/step
# Epoch 94/100
# 222/222 - 0s - loss: 0.0015 - 200ms/epoch - 901us/step
# Epoch 95/100
# 222/222 - 0s - loss: 0.0012 - 288ms/epoch - 1ms/step
# Epoch 96/100
# 222/222 - 0s - loss: 0.0013 - 221ms/epoch - 996us/step
# Epoch 97/100
# 222/222 - 0s - loss: 0.0012 - 210ms/epoch - 947us/step
# Epoch 98/100
# 222/222 - 0s - loss: 0.0013 - 318ms/epoch - 1ms/step
# Epoch 99/100
# 222/222 - 0s - loss: 0.0013 - 216ms/epoch - 972us/step
# Epoch 100/100
# 222/222 - 0s - loss: 0.0013 - 212ms/epoch - 956us/step
# 63
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# Next values:  [18.934753, 19.064669, 19.040531, 19.079317, 18.847445, 18.905346, 18.626108, 17.943352, 18.348343, 18.472185, 18.517677, 18.717802, 18.681946, 18.66319, 18.972904, 19.062714, 19.50649, 19.688288, 19.73651, 19.733839, 19.977417, 20.047417, 19.692295, 19.848677, 19.813377, 19.952051, 19.896503, 20.165607, 20.370602, 20.781782, 36.321136, 32.964333, 36.048203, 29.868793, 29.748058, 29.741602, 29.74127, 29.741282, 29.741262, 29.74125, 29.741278, 29.738613, 29.739891, 29.74074, 29.741282, 29.74127, 29.741282, 29.741282, 29.741282, 29.741282, 29.741282, 29.741282, 29.741282, 29.741282, 29.741282, 29.741278, 29.741282, 29.741282, 29.741282, 29.741282, 29.741282, 29.741282, 29.741282]
# Test Score: 6.30 RMSE

# %%
model_LSTM(pre_LSTM(data1), 60)
# Out:
# Epoch 1/100
# 192/192 - 1s - loss: 0.0432 - 1s/epoch - 8ms/step
# Epoch 2/100
# 192/192 - 0s - loss: 0.0108 - 187ms/epoch - 976us/step
# Epoch 3/100
# 192/192 - 0s - loss: 0.0072 - 192ms/epoch - 998us/step
# Epoch 4/100
# 192/192 - 0s - loss: 0.0061 - 184ms/epoch - 958us/step
# Epoch 5/100
# 192/192 - 0s - loss: 0.0054 - 183ms/epoch - 952us/step
# Epoch 6/100
# 192/192 - 0s - loss: 0.0048 - 196ms/epoch - 1ms/step
# Epoch 7/100
# 192/192 - 0s - loss: 0.0044 - 188ms/epoch - 977us/step
# Epoch 8/100
# 192/192 - 0s - loss: 0.0040 - 184ms/epoch - 958us/step
# Epoch 9/100
# 192/192 - 0s - loss: 0.0037 - 191ms/epoch - 993us/step
# Epoch 10/100
# 192/192 - 0s - loss: 0.0037 - 191ms/epoch - 993us/step
# Epoch 11/100
# 192/192 - 0s - loss: 0.0033 - 187ms/epoch - 974us/step
# Epoch 12/100
# 192/192 - 0s - loss: 0.0032 - 246ms/epoch - 1ms/step
# Epoch 13/100
# 192/192 - 0s - loss: 0.0030 - 193ms/epoch - 1ms/step
# Epoch 14/100
# 192/192 - 0s - loss: 0.0029 - 207ms/epoch - 1ms/step
# Epoch 15/100
# 192/192 - 0s - loss: 0.0026 - 203ms/epoch - 1ms/step
# Epoch 16/100
# 192/192 - 0s - loss: 0.0026 - 214ms/epoch - 1ms/step
# Epoch 17/100
# 192/192 - 0s - loss: 0.0025 - 193ms/epoch - 1ms/step
# Epoch 18/100
# 192/192 - 0s - loss: 0.0024 - 179ms/epoch - 934us/step
# Epoch 19/100
# 192/192 - 0s - loss: 0.0023 - 180ms/epoch - 938us/step
# Epoch 20/100
# 192/192 - 0s - loss: 0.0026 - 205ms/epoch - 1ms/step
# Epoch 21/100
# 192/192 - 0s - loss: 0.0022 - 190ms/epoch - 991us/step
# Epoch 22/100
# 192/192 - 0s - loss: 0.0021 - 251ms/epoch - 1ms/step
# Epoch 23/100
# 192/192 - 0s - loss: 0.0020 - 204ms/epoch - 1ms/step
# Epoch 24/100
# 192/192 - 0s - loss: 0.0020 - 200ms/epoch - 1ms/step
# Epoch 25/100
# 192/192 - 0s - loss: 0.0019 - 186ms/epoch - 970us/step
# Epoch 26/100
# 192/192 - 0s - loss: 0.0019 - 193ms/epoch - 1ms/step
# Epoch 27/100
# 192/192 - 0s - loss: 0.0020 - 202ms/epoch - 1ms/step
# Epoch 28/100
# 192/192 - 0s - loss: 0.0020 - 182ms/epoch - 947us/step
# Epoch 29/100
# 192/192 - 0s - loss: 0.0018 - 183ms/epoch - 953us/step
# Epoch 30/100
# 192/192 - 0s - loss: 0.0018 - 199ms/epoch - 1ms/step
# Epoch 31/100
# 192/192 - 0s - loss: 0.0017 - 184ms/epoch - 958us/step
# Epoch 32/100
# 192/192 - 0s - loss: 0.0018 - 198ms/epoch - 1ms/step
# Epoch 33/100
# 192/192 - 0s - loss: 0.0016 - 185ms/epoch - 963us/step
# Epoch 34/100
# 192/192 - 0s - loss: 0.0016 - 221ms/epoch - 1ms/step
# Epoch 35/100
# 192/192 - 0s - loss: 0.0017 - 185ms/epoch - 964us/step
# Epoch 36/100
# 192/192 - 0s - loss: 0.0015 - 181ms/epoch - 942us/step
# Epoch 37/100
# 192/192 - 0s - loss: 0.0015 - 209ms/epoch - 1ms/step
# Epoch 38/100
# 192/192 - 0s - loss: 0.0015 - 220ms/epoch - 1ms/step
# Epoch 39/100
# 192/192 - 0s - loss: 0.0015 - 181ms/epoch - 944us/step
# Epoch 40/100
# 192/192 - 0s - loss: 0.0015 - 177ms/epoch - 923us/step
# Epoch 41/100
# 192/192 - 0s - loss: 0.0014 - 254ms/epoch - 1ms/step
# Epoch 42/100
# 192/192 - 0s - loss: 0.0014 - 186ms/epoch - 971us/step
# Epoch 43/100
# 192/192 - 0s - loss: 0.0013 - 189ms/epoch - 986us/step
# Epoch 44/100
# 192/192 - 0s - loss: 0.0014 - 189ms/epoch - 986us/step
# Epoch 45/100
# 192/192 - 0s - loss: 0.0014 - 206ms/epoch - 1ms/step
# Epoch 46/100
# 192/192 - 0s - loss: 0.0014 - 198ms/epoch - 1ms/step
# Epoch 47/100
# 192/192 - 0s - loss: 0.0013 - 197ms/epoch - 1ms/step
# Epoch 48/100
# 192/192 - 0s - loss: 0.0013 - 205ms/epoch - 1ms/step
# Epoch 49/100
# 192/192 - 0s - loss: 0.0013 - 211ms/epoch - 1ms/step
# Epoch 50/100
# 192/192 - 0s - loss: 0.0013 - 202ms/epoch - 1ms/step
# Epoch 51/100
# 192/192 - 0s - loss: 0.0014 - 213ms/epoch - 1ms/step
# Epoch 52/100
# 192/192 - 0s - loss: 0.0013 - 207ms/epoch - 1ms/step
# Epoch 53/100
# 192/192 - 0s - loss: 0.0012 - 201ms/epoch - 1ms/step
# Epoch 54/100
# 192/192 - 0s - loss: 0.0012 - 209ms/epoch - 1ms/step
# Epoch 55/100
# 192/192 - 0s - loss: 0.0013 - 190ms/epoch - 991us/step
# Epoch 56/100
# 192/192 - 0s - loss: 0.0012 - 205ms/epoch - 1ms/step
# Epoch 57/100
# 192/192 - 0s - loss: 0.0012 - 223ms/epoch - 1ms/step
# Epoch 58/100
# 192/192 - 0s - loss: 0.0012 - 231ms/epoch - 1ms/step
# Epoch 59/100
# 192/192 - 0s - loss: 0.0012 - 252ms/epoch - 1ms/step
# Epoch 60/100
# 192/192 - 0s - loss: 0.0012 - 208ms/epoch - 1ms/step
# Epoch 61/100
# 192/192 - 0s - loss: 0.0013 - 217ms/epoch - 1ms/step
# Epoch 62/100
# 192/192 - 0s - loss: 0.0011 - 208ms/epoch - 1ms/step
# Epoch 63/100
# 192/192 - 0s - loss: 0.0012 - 222ms/epoch - 1ms/step
# Epoch 64/100
# 192/192 - 0s - loss: 0.0011 - 213ms/epoch - 1ms/step
# Epoch 65/100
# 192/192 - 0s - loss: 0.0011 - 228ms/epoch - 1ms/step
# Epoch 66/100
# 192/192 - 0s - loss: 0.0011 - 215ms/epoch - 1ms/step
# Epoch 67/100
# 192/192 - 0s - loss: 0.0011 - 213ms/epoch - 1ms/step
# Epoch 68/100
# 192/192 - 0s - loss: 0.0012 - 210ms/epoch - 1ms/step
# Epoch 69/100
# 192/192 - 0s - loss: 0.0011 - 221ms/epoch - 1ms/step
# Epoch 70/100
# 192/192 - 0s - loss: 0.0012 - 206ms/epoch - 1ms/step
# Epoch 71/100
# 192/192 - 0s - loss: 0.0011 - 216ms/epoch - 1ms/step
# Epoch 72/100
# 192/192 - 0s - loss: 0.0011 - 221ms/epoch - 1ms/step
# Epoch 73/100
# 192/192 - 0s - loss: 0.0010 - 220ms/epoch - 1ms/step
# Epoch 74/100
# 192/192 - 0s - loss: 0.0010 - 233ms/epoch - 1ms/step
# Epoch 75/100
# 192/192 - 0s - loss: 0.0011 - 218ms/epoch - 1ms/step
# Epoch 76/100
# 192/192 - 0s - loss: 0.0011 - 222ms/epoch - 1ms/step
# Epoch 77/100
# 192/192 - 0s - loss: 0.0014 - 224ms/epoch - 1ms/step
# Epoch 78/100
# 192/192 - 0s - loss: 9.8934e-04 - 228ms/epoch - 1ms/step
# Epoch 79/100
# 192/192 - 0s - loss: 0.0010 - 218ms/epoch - 1ms/step
# Epoch 80/100
# 192/192 - 0s - loss: 0.0010 - 219ms/epoch - 1ms/step
# Epoch 81/100
# 192/192 - 0s - loss: 9.1360e-04 - 228ms/epoch - 1ms/step
# Epoch 82/100
# 192/192 - 0s - loss: 9.7980e-04 - 232ms/epoch - 1ms/step
# Epoch 83/100
# 192/192 - 0s - loss: 0.0011 - 289ms/epoch - 2ms/step
# Epoch 84/100
# 192/192 - 0s - loss: 9.7239e-04 - 237ms/epoch - 1ms/step
# Epoch 85/100
# 192/192 - 0s - loss: 9.3961e-04 - 226ms/epoch - 1ms/step
# Epoch 86/100
# 192/192 - 0s - loss: 9.1587e-04 - 227ms/epoch - 1ms/step
# Epoch 87/100
# 192/192 - 0s - loss: 0.0010 - 276ms/epoch - 1ms/step
# Epoch 88/100
# 192/192 - 0s - loss: 9.8816e-04 - 269ms/epoch - 1ms/step
# Epoch 89/100
# 192/192 - 0s - loss: 9.7206e-04 - 238ms/epoch - 1ms/step
# Epoch 90/100
# 192/192 - 0s - loss: 9.6736e-04 - 247ms/epoch - 1ms/step
# Epoch 91/100
# 192/192 - 0s - loss: 9.3043e-04 - 277ms/epoch - 1ms/step
# Epoch 92/100
# 192/192 - 0s - loss: 9.9849e-04 - 236ms/epoch - 1ms/step
# Epoch 93/100
# 192/192 - 0s - loss: 0.0011 - 255ms/epoch - 1ms/step
# Epoch 94/100
# 192/192 - 0s - loss: 9.2068e-04 - 352ms/epoch - 2ms/step
# Epoch 95/100
# 192/192 - 0s - loss: 9.4946e-04 - 244ms/epoch - 1ms/step
# Epoch 96/100
# 192/192 - 0s - loss: 9.1681e-04 - 233ms/epoch - 1ms/step
# Epoch 97/100
# 192/192 - 0s - loss: 8.5623e-04 - 256ms/epoch - 1ms/step
# Epoch 98/100
# 192/192 - 0s - loss: 9.7576e-04 - 232ms/epoch - 1ms/step
# Epoch 99/100
# 192/192 - 0s - loss: 8.2904e-04 - 249ms/epoch - 1ms/step
# Epoch 100/100
# 192/192 - 0s - loss: 8.8502e-04 - 279ms/epoch - 1ms/step
# 63
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Next values:  [14.368346, 14.422574, 14.607046, 14.804829, 14.8910265, 14.954712, 15.122812, 15.112854, 15.234075, 15.05173, 15.071075, 15.074292, 14.861564, 14.504119, 14.326835, 14.170867, 14.02774, 14.331452, 14.597701, 14.9785795, 15.292046, 15.632341, 16.29215, 16.757093, 17.614794, 18.038486, 18.368162, 18.350197, 17.92556, 18.03285, 18.53736, 18.552176, 18.370295, 18.543877, 18.653011, 18.67605, 18.42655, 17.793371, 18.077261, 18.177402, 18.012482, 18.105446, 17.958395, 18.017555, 18.320803, 18.455645, 18.898151, 19.140514, 19.152885, 19.155428, 19.319628, 19.288412, 19.177628, 19.354061, 19.348104, 19.469501, 19.557972, 19.986246, 20.242414, 20.40795, 28.614586, 30.14238, 30.477962]
# Test Score: 5.54 RMSE

# %%
model_LSTM(pre_LSTM(data1), 90)
# Out:
# Epoch 1/100
# 162/162 - 2s - loss: 0.0272 - 2s/epoch - 12ms/step
# Epoch 2/100
# 162/162 - 0s - loss: 0.0064 - 220ms/epoch - 1ms/step
# Epoch 3/100
# 162/162 - 0s - loss: 0.0050 - 195ms/epoch - 1ms/step
# Epoch 4/100
# 162/162 - 0s - loss: 0.0043 - 221ms/epoch - 1ms/step
# Epoch 5/100
# 162/162 - 0s - loss: 0.0040 - 224ms/epoch - 1ms/step
# Epoch 6/100
# 162/162 - 0s - loss: 0.0034 - 185ms/epoch - 1ms/step
# Epoch 7/100
# 162/162 - 0s - loss: 0.0031 - 198ms/epoch - 1ms/step
# Epoch 8/100
# 162/162 - 0s - loss: 0.0030 - 197ms/epoch - 1ms/step
# Epoch 9/100
# 162/162 - 0s - loss: 0.0028 - 207ms/epoch - 1ms/step
# Epoch 10/100
# 162/162 - 0s - loss: 0.0024 - 187ms/epoch - 1ms/step
# Epoch 11/100
# 162/162 - 0s - loss: 0.0024 - 209ms/epoch - 1ms/step
# Epoch 12/100
# 162/162 - 0s - loss: 0.0024 - 227ms/epoch - 1ms/step
# Epoch 13/100
# 162/162 - 0s - loss: 0.0020 - 242ms/epoch - 1ms/step
# Epoch 14/100
# 162/162 - 0s - loss: 0.0020 - 236ms/epoch - 1ms/step
# Epoch 15/100
# 162/162 - 0s - loss: 0.0019 - 190ms/epoch - 1ms/step
# Epoch 16/100
# 162/162 - 0s - loss: 0.0020 - 205ms/epoch - 1ms/step
# Epoch 17/100
# 162/162 - 0s - loss: 0.0018 - 201ms/epoch - 1ms/step
# Epoch 18/100
# 162/162 - 0s - loss: 0.0017 - 213ms/epoch - 1ms/step
# Epoch 19/100
# 162/162 - 0s - loss: 0.0018 - 207ms/epoch - 1ms/step
# Epoch 20/100
# 162/162 - 0s - loss: 0.0015 - 200ms/epoch - 1ms/step
# Epoch 21/100
# 162/162 - 0s - loss: 0.0016 - 225ms/epoch - 1ms/step
# Epoch 22/100
# 162/162 - 0s - loss: 0.0015 - 217ms/epoch - 1ms/step
# Epoch 23/100
# 162/162 - 0s - loss: 0.0014 - 217ms/epoch - 1ms/step
# Epoch 24/100
# 162/162 - 0s - loss: 0.0014 - 211ms/epoch - 1ms/step
# Epoch 25/100
# 162/162 - 0s - loss: 0.0014 - 229ms/epoch - 1ms/step
# Epoch 26/100
# 162/162 - 0s - loss: 0.0013 - 248ms/epoch - 2ms/step
# Epoch 27/100
# 162/162 - 0s - loss: 0.0012 - 244ms/epoch - 2ms/step
# Epoch 28/100
# 162/162 - 0s - loss: 0.0014 - 251ms/epoch - 2ms/step
# Epoch 29/100
# 162/162 - 0s - loss: 0.0011 - 281ms/epoch - 2ms/step
# Epoch 30/100
# 162/162 - 0s - loss: 0.0011 - 333ms/epoch - 2ms/step
# Epoch 31/100
# 162/162 - 0s - loss: 0.0011 - 209ms/epoch - 1ms/step
# Epoch 32/100
# 162/162 - 0s - loss: 0.0010 - 209ms/epoch - 1ms/step
# Epoch 33/100
# 162/162 - 0s - loss: 0.0010 - 237ms/epoch - 1ms/step
# Epoch 34/100
# 162/162 - 0s - loss: 0.0011 - 285ms/epoch - 2ms/step
# Epoch 35/100
# 162/162 - 0s - loss: 0.0010 - 289ms/epoch - 2ms/step
# Epoch 36/100
# 162/162 - 0s - loss: 0.0011 - 264ms/epoch - 2ms/step
# Epoch 37/100
# 162/162 - 0s - loss: 0.0010 - 220ms/epoch - 1ms/step
# Epoch 38/100
# 162/162 - 0s - loss: 9.5615e-04 - 242ms/epoch - 1ms/step
# Epoch 39/100
# 162/162 - 0s - loss: 0.0011 - 287ms/epoch - 2ms/step
# Epoch 40/100
# 162/162 - 0s - loss: 9.8641e-04 - 231ms/epoch - 1ms/step
# Epoch 41/100
# 162/162 - 0s - loss: 8.9790e-04 - 251ms/epoch - 2ms/step
# Epoch 42/100
# 162/162 - 0s - loss: 9.3993e-04 - 271ms/epoch - 2ms/step
# Epoch 43/100
# 162/162 - 0s - loss: 7.9922e-04 - 253ms/epoch - 2ms/step
# Epoch 44/100
# 162/162 - 0s - loss: 9.5916e-04 - 240ms/epoch - 1ms/step
# Epoch 45/100
# 162/162 - 0s - loss: 8.6753e-04 - 254ms/epoch - 2ms/step
# Epoch 46/100
# 162/162 - 0s - loss: 7.5476e-04 - 225ms/epoch - 1ms/step
# Epoch 47/100
# 162/162 - 0s - loss: 8.0699e-04 - 228ms/epoch - 1ms/step
# Epoch 48/100
# 162/162 - 0s - loss: 7.5240e-04 - 241ms/epoch - 1ms/step
# Epoch 49/100
# 162/162 - 0s - loss: 7.1658e-04 - 213ms/epoch - 1ms/step
# Epoch 50/100
# 162/162 - 0s - loss: 7.4651e-04 - 238ms/epoch - 1ms/step
# Epoch 51/100
# 162/162 - 0s - loss: 7.9433e-04 - 265ms/epoch - 2ms/step
# Epoch 52/100
# 162/162 - 0s - loss: 7.3660e-04 - 211ms/epoch - 1ms/step
# Epoch 53/100
# 162/162 - 0s - loss: 6.4133e-04 - 241ms/epoch - 1ms/step
# Epoch 54/100
# 162/162 - 0s - loss: 7.4154e-04 - 249ms/epoch - 2ms/step
# Epoch 55/100
# 162/162 - 0s - loss: 7.4587e-04 - 224ms/epoch - 1ms/step
# Epoch 56/100
# 162/162 - 0s - loss: 7.5017e-04 - 230ms/epoch - 1ms/step
# Epoch 57/100
# 162/162 - 0s - loss: 7.1441e-04 - 236ms/epoch - 1ms/step
# Epoch 58/100
# 162/162 - 0s - loss: 6.0416e-04 - 271ms/epoch - 2ms/step
# Epoch 59/100
# 162/162 - 0s - loss: 7.0171e-04 - 266ms/epoch - 2ms/step
# Epoch 60/100
# 162/162 - 0s - loss: 6.1955e-04 - 227ms/epoch - 1ms/step
# Epoch 61/100
# 162/162 - 0s - loss: 6.8272e-04 - 263ms/epoch - 2ms/step
# Epoch 62/100
# 162/162 - 0s - loss: 6.2176e-04 - 262ms/epoch - 2ms/step
# Epoch 63/100
# 162/162 - 0s - loss: 6.3292e-04 - 220ms/epoch - 1ms/step
# Epoch 64/100
# 162/162 - 0s - loss: 8.5364e-04 - 252ms/epoch - 2ms/step
# Epoch 65/100
# 162/162 - 0s - loss: 6.2963e-04 - 249ms/epoch - 2ms/step
# Epoch 66/100
# 162/162 - 0s - loss: 6.6903e-04 - 253ms/epoch - 2ms/step
# Epoch 67/100
# 162/162 - 0s - loss: 5.9384e-04 - 309ms/epoch - 2ms/step
# Epoch 68/100
# 162/162 - 0s - loss: 6.2090e-04 - 310ms/epoch - 2ms/step
# Epoch 69/100
# 162/162 - 0s - loss: 6.8122e-04 - 275ms/epoch - 2ms/step
# Epoch 70/100
# 162/162 - 0s - loss: 6.6415e-04 - 215ms/epoch - 1ms/step
# Epoch 71/100
# 162/162 - 0s - loss: 5.5647e-04 - 274ms/epoch - 2ms/step
# Epoch 72/100
# 162/162 - 0s - loss: 6.5500e-04 - 253ms/epoch - 2ms/step
# Epoch 73/100
# 162/162 - 0s - loss: 5.6525e-04 - 276ms/epoch - 2ms/step
# Epoch 74/100
# 162/162 - 0s - loss: 5.4434e-04 - 255ms/epoch - 2ms/step
# Epoch 75/100
# 162/162 - 0s - loss: 5.7642e-04 - 252ms/epoch - 2ms/step
# Epoch 76/100
# 162/162 - 0s - loss: 6.3649e-04 - 225ms/epoch - 1ms/step
# Epoch 77/100
# 162/162 - 0s - loss: 7.6316e-04 - 219ms/epoch - 1ms/step
# Epoch 78/100
# 162/162 - 0s - loss: 6.7350e-04 - 225ms/epoch - 1ms/step
# Epoch 79/100
# 162/162 - 0s - loss: 5.8355e-04 - 222ms/epoch - 1ms/step
# Epoch 80/100
# 162/162 - 0s - loss: 5.1379e-04 - 227ms/epoch - 1ms/step
# Epoch 81/100
# 162/162 - 0s - loss: 5.3656e-04 - 221ms/epoch - 1ms/step
# Epoch 82/100
# 162/162 - 0s - loss: 6.3391e-04 - 219ms/epoch - 1ms/step
# Epoch 83/100
# 162/162 - 0s - loss: 5.1003e-04 - 228ms/epoch - 1ms/step
# Epoch 84/100
# 162/162 - 0s - loss: 5.1666e-04 - 218ms/epoch - 1ms/step
# Epoch 85/100
# 162/162 - 0s - loss: 6.4104e-04 - 248ms/epoch - 2ms/step
# Epoch 86/100
# 162/162 - 0s - loss: 5.7070e-04 - 231ms/epoch - 1ms/step
# Epoch 87/100
# 162/162 - 0s - loss: 5.0289e-04 - 213ms/epoch - 1ms/step
# Epoch 88/100
# 162/162 - 0s - loss: 4.4049e-04 - 206ms/epoch - 1ms/step
# Epoch 89/100
# 162/162 - 0s - loss: 5.3877e-04 - 240ms/epoch - 1ms/step
# Epoch 90/100
# 162/162 - 0s - loss: 5.4437e-04 - 216ms/epoch - 1ms/step
# Epoch 91/100
# 162/162 - 0s - loss: 6.3381e-04 - 306ms/epoch - 2ms/step
# Epoch 92/100
# 162/162 - 0s - loss: 4.6279e-04 - 209ms/epoch - 1ms/step
# Epoch 93/100
# 162/162 - 0s - loss: 5.2361e-04 - 209ms/epoch - 1ms/step
# Epoch 94/100
# 162/162 - 0s - loss: 6.7712e-04 - 221ms/epoch - 1ms/step
# Epoch 95/100
# 162/162 - 0s - loss: 5.7446e-04 - 217ms/epoch - 1ms/step
# Epoch 96/100
# 162/162 - 0s - loss: 5.6137e-04 - 231ms/epoch - 1ms/step
# Epoch 97/100
# 162/162 - 0s - loss: 5.1123e-04 - 211ms/epoch - 1ms/step
# Epoch 98/100
# 162/162 - 0s - loss: 5.7935e-04 - 204ms/epoch - 1ms/step
# Epoch 99/100
# 162/162 - 0s - loss: 4.7716e-04 - 212ms/epoch - 1ms/step
# Epoch 100/100
# 162/162 - 0s - loss: 4.6592e-04 - 209ms/epoch - 1ms/step
# 63
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# Next values:  [15.493416, 15.290375, 15.184985, 15.010622, 14.9537525, 14.804397, 14.628613, 14.628361, 14.603335, 14.623079, 14.718778, 14.694035, 14.643279, 14.51988, 14.61624, 14.526671, 14.446793, 14.3055, 14.166681, 14.141206, 14.136412, 14.316406, 14.3719015, 14.342345, 14.327492, 14.536405, 14.561473, 14.602957, 14.686193, 14.593878, 14.576438, 14.588822, 14.776926, 14.945385, 14.917113, 15.066384, 15.108689, 15.217345, 15.34488, 15.221784, 15.081321, 14.837873, 14.747403, 14.575905, 14.400104, 14.27613, 14.1736355, 14.508116, 14.950288, 15.276391, 15.692717, 16.170246, 16.979916, 17.557606, 18.263586, 18.64584, 18.838383, 18.585917, 18.46149, 18.829668, 19.121763, 19.160357, 18.89348]
# Test Score: 6.86 RMSE

# %% [markdown]
# ### Weekly basis

# %%
model_LSTM(pre_LSTM(data1W), 2)
# Out:
# Epoch 1/100
# 50/50 - 2s - loss: 0.1298 - 2s/epoch - 42ms/step
# Epoch 2/100
# 50/50 - 0s - loss: 0.0828 - 78ms/epoch - 2ms/step
# Epoch 3/100
# 50/50 - 0s - loss: 0.0522 - 54ms/epoch - 1ms/step
# Epoch 4/100
# 50/50 - 0s - loss: 0.0361 - 61ms/epoch - 1ms/step
# Epoch 5/100
# 50/50 - 0s - loss: 0.0287 - 52ms/epoch - 1ms/step
# Epoch 6/100
# 50/50 - 0s - loss: 0.0261 - 51ms/epoch - 1ms/step
# Epoch 7/100
# 50/50 - 0s - loss: 0.0246 - 78ms/epoch - 2ms/step
# Epoch 8/100
# 50/50 - 0s - loss: 0.0233 - 61ms/epoch - 1ms/step
# Epoch 9/100
# 50/50 - 0s - loss: 0.0226 - 54ms/epoch - 1ms/step
# Epoch 10/100
# 50/50 - 0s - loss: 0.0214 - 54ms/epoch - 1ms/step
# Epoch 11/100
# 50/50 - 0s - loss: 0.0206 - 61ms/epoch - 1ms/step
# Epoch 12/100
# 50/50 - 0s - loss: 0.0198 - 61ms/epoch - 1ms/step
# Epoch 13/100
# 50/50 - 0s - loss: 0.0190 - 62ms/epoch - 1ms/step
# Epoch 14/100
# 50/50 - 0s - loss: 0.0183 - 58ms/epoch - 1ms/step
# Epoch 15/100
# 50/50 - 0s - loss: 0.0179 - 63ms/epoch - 1ms/step
# Epoch 16/100
# 50/50 - 0s - loss: 0.0169 - 59ms/epoch - 1ms/step
# Epoch 17/100
# 50/50 - 0s - loss: 0.0165 - 55ms/epoch - 1ms/step
# Epoch 18/100
# 50/50 - 0s - loss: 0.0159 - 57ms/epoch - 1ms/step
# Epoch 19/100
# 50/50 - 0s - loss: 0.0154 - 52ms/epoch - 1ms/step
# Epoch 20/100
# 50/50 - 0s - loss: 0.0160 - 60ms/epoch - 1ms/step
# Epoch 21/100
# 50/50 - 0s - loss: 0.0147 - 57ms/epoch - 1ms/step
# Epoch 22/100
# 50/50 - 0s - loss: 0.0142 - 56ms/epoch - 1ms/step
# Epoch 23/100
# 50/50 - 0s - loss: 0.0140 - 55ms/epoch - 1ms/step
# Epoch 24/100
# 50/50 - 0s - loss: 0.0137 - 51ms/epoch - 1ms/step
# Epoch 25/100
# 50/50 - 0s - loss: 0.0133 - 53ms/epoch - 1ms/step
# Epoch 26/100
# 50/50 - 0s - loss: 0.0130 - 68ms/epoch - 1ms/step
# Epoch 27/100
# 50/50 - 0s - loss: 0.0128 - 62ms/epoch - 1ms/step
# Epoch 28/100
# 50/50 - 0s - loss: 0.0128 - 59ms/epoch - 1ms/step
# Epoch 29/100
# 50/50 - 0s - loss: 0.0125 - 52ms/epoch - 1ms/step
# Epoch 30/100
# 50/50 - 0s - loss: 0.0126 - 52ms/epoch - 1ms/step
# Epoch 31/100
# 50/50 - 0s - loss: 0.0123 - 52ms/epoch - 1ms/step
# Epoch 32/100
# 50/50 - 0s - loss: 0.0120 - 62ms/epoch - 1ms/step
# Epoch 33/100
# 50/50 - 0s - loss: 0.0118 - 57ms/epoch - 1ms/step
# Epoch 34/100
# 50/50 - 0s - loss: 0.0118 - 65ms/epoch - 1ms/step
# Epoch 35/100
# 50/50 - 0s - loss: 0.0118 - 68ms/epoch - 1ms/step
# Epoch 36/100
# 50/50 - 0s - loss: 0.0114 - 56ms/epoch - 1ms/step
# Epoch 37/100
# 50/50 - 0s - loss: 0.0113 - 61ms/epoch - 1ms/step
# Epoch 38/100
# 50/50 - 0s - loss: 0.0112 - 63ms/epoch - 1ms/step
# Epoch 39/100
# 50/50 - 0s - loss: 0.0111 - 55ms/epoch - 1ms/step
# Epoch 40/100
# 50/50 - 0s - loss: 0.0108 - 78ms/epoch - 2ms/step
# Epoch 41/100
# 50/50 - 0s - loss: 0.0109 - 66ms/epoch - 1ms/step
# Epoch 42/100
# 50/50 - 0s - loss: 0.0106 - 96ms/epoch - 2ms/step
# Epoch 43/100
# 50/50 - 0s - loss: 0.0103 - 55ms/epoch - 1ms/step
# Epoch 44/100
# 50/50 - 0s - loss: 0.0105 - 51ms/epoch - 1ms/step
# Epoch 45/100
# 50/50 - 0s - loss: 0.0101 - 56ms/epoch - 1ms/step
# Epoch 46/100
# 50/50 - 0s - loss: 0.0105 - 52ms/epoch - 1ms/step
# Epoch 47/100
# 50/50 - 0s - loss: 0.0100 - 56ms/epoch - 1ms/step
# Epoch 48/100
# 50/50 - 0s - loss: 0.0099 - 51ms/epoch - 1ms/step
# Epoch 49/100
# 50/50 - 0s - loss: 0.0098 - 50ms/epoch - 1ms/step
# Epoch 50/100
# 50/50 - 0s - loss: 0.0095 - 57ms/epoch - 1ms/step
# Epoch 51/100
# 50/50 - 0s - loss: 0.0094 - 59ms/epoch - 1ms/step
# Epoch 52/100
# 50/50 - 0s - loss: 0.0094 - 60ms/epoch - 1ms/step
# Epoch 53/100
# 50/50 - 0s - loss: 0.0091 - 92ms/epoch - 2ms/step
# Epoch 54/100
# 50/50 - 0s - loss: 0.0090 - 58ms/epoch - 1ms/step
# Epoch 55/100
# 50/50 - 0s - loss: 0.0091 - 56ms/epoch - 1ms/step
# Epoch 56/100
# 50/50 - 0s - loss: 0.0087 - 53ms/epoch - 1ms/step
# Epoch 57/100
# 50/50 - 0s - loss: 0.0091 - 52ms/epoch - 1ms/step
# Epoch 58/100
# 50/50 - 0s - loss: 0.0086 - 54ms/epoch - 1ms/step
# Epoch 59/100
# 50/50 - 0s - loss: 0.0085 - 54ms/epoch - 1ms/step
# Epoch 60/100
# 50/50 - 0s - loss: 0.0083 - 54ms/epoch - 1ms/step
# Epoch 61/100
# 50/50 - 0s - loss: 0.0082 - 59ms/epoch - 1ms/step
# Epoch 62/100
# 50/50 - 0s - loss: 0.0084 - 53ms/epoch - 1ms/step
# Epoch 63/100
# 50/50 - 0s - loss: 0.0080 - 57ms/epoch - 1ms/step
# Epoch 64/100
# 50/50 - 0s - loss: 0.0078 - 55ms/epoch - 1ms/step
# Epoch 65/100
# 50/50 - 0s - loss: 0.0077 - 54ms/epoch - 1ms/step
# Epoch 66/100
# 50/50 - 0s - loss: 0.0077 - 53ms/epoch - 1ms/step
# Epoch 67/100
# 50/50 - 0s - loss: 0.0076 - 71ms/epoch - 1ms/step
# Epoch 68/100
# 50/50 - 0s - loss: 0.0074 - 64ms/epoch - 1ms/step
# Epoch 69/100
# 50/50 - 0s - loss: 0.0073 - 53ms/epoch - 1ms/step
# Epoch 70/100
# 50/50 - 0s - loss: 0.0072 - 54ms/epoch - 1ms/step
# Epoch 71/100
# 50/50 - 0s - loss: 0.0072 - 61ms/epoch - 1ms/step
# Epoch 72/100
# 50/50 - 0s - loss: 0.0071 - 62ms/epoch - 1ms/step
# Epoch 73/100
# 50/50 - 0s - loss: 0.0069 - 77ms/epoch - 2ms/step
# Epoch 74/100
# 50/50 - 0s - loss: 0.0070 - 57ms/epoch - 1ms/step
# Epoch 75/100
# 50/50 - 0s - loss: 0.0069 - 55ms/epoch - 1ms/step
# Epoch 76/100
# 50/50 - 0s - loss: 0.0068 - 58ms/epoch - 1ms/step
# Epoch 77/100
# 50/50 - 0s - loss: 0.0066 - 52ms/epoch - 1ms/step
# Epoch 78/100
# 50/50 - 0s - loss: 0.0066 - 70ms/epoch - 1ms/step
# Epoch 79/100
# 50/50 - 0s - loss: 0.0066 - 56ms/epoch - 1ms/step
# Epoch 80/100
# 50/50 - 0s - loss: 0.0064 - 54ms/epoch - 1ms/step
# Epoch 81/100
# 50/50 - 0s - loss: 0.0065 - 56ms/epoch - 1ms/step
# Epoch 82/100
# 50/50 - 0s - loss: 0.0063 - 53ms/epoch - 1ms/step
# Epoch 83/100
# 50/50 - 0s - loss: 0.0064 - 58ms/epoch - 1ms/step
# Epoch 84/100
# 50/50 - 0s - loss: 0.0061 - 51ms/epoch - 1ms/step
# Epoch 85/100
# 50/50 - 0s - loss: 0.0061 - 54ms/epoch - 1ms/step
# Epoch 86/100
# 50/50 - 0s - loss: 0.0060 - 52ms/epoch - 1ms/step
# Epoch 87/100
# 50/50 - 0s - loss: 0.0059 - 59ms/epoch - 1ms/step
# Epoch 88/100
# 50/50 - 0s - loss: 0.0059 - 54ms/epoch - 1ms/step
# Epoch 89/100
# 50/50 - 0s - loss: 0.0059 - 60ms/epoch - 1ms/step
# Epoch 90/100
# 50/50 - 0s - loss: 0.0060 - 54ms/epoch - 1ms/step
# Epoch 91/100
# 50/50 - 0s - loss: 0.0058 - 52ms/epoch - 1ms/step
# Epoch 92/100
# 50/50 - 0s - loss: 0.0057 - 52ms/epoch - 1ms/step
# Epoch 93/100
# 50/50 - 0s - loss: 0.0057 - 55ms/epoch - 1ms/step
# Epoch 94/100
# 50/50 - 0s - loss: 0.0058 - 73ms/epoch - 1ms/step
# Epoch 95/100
# 50/50 - 0s - loss: 0.0056 - 64ms/epoch - 1ms/step
# Epoch 96/100
# 50/50 - 0s - loss: 0.0059 - 61ms/epoch - 1ms/step
# Epoch 97/100
# 50/50 - 0s - loss: 0.0056 - 62ms/epoch - 1ms/step
# Epoch 98/100
# 50/50 - 0s - loss: 0.0057 - 59ms/epoch - 1ms/step
# Epoch 99/100
# 50/50 - 0s - loss: 0.0055 - 57ms/epoch - 1ms/step
# Epoch 100/100
# 50/50 - 0s - loss: 0.0055 - 53ms/epoch - 1ms/step
# 14
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# Next values:  [18.610502, 19.736233, 45.28704, 37.61042, 44.780766, 36.613342, 36.876335, 36.60929, 36.6951, 36.684425, 36.692375, 36.689987, 36.690376, 36.69014]
# Test Score: 15.45 RMSE

# %%
model_LSTM(pre_LSTM(data1W), 10)
# Out:
# Epoch 1/100
# 42/42 - 1s - loss: 0.1120 - 1s/epoch - 34ms/step
# Epoch 2/100
# 42/42 - 0s - loss: 0.0739 - 52ms/epoch - 1ms/step
# Epoch 3/100
# 42/42 - 0s - loss: 0.0574 - 44ms/epoch - 1ms/step
# Epoch 4/100
# 42/42 - 0s - loss: 0.0476 - 42ms/epoch - 994us/step
# Epoch 5/100
# 42/42 - 0s - loss: 0.0415 - 44ms/epoch - 1ms/step
# Epoch 6/100
# 42/42 - 0s - loss: 0.0361 - 45ms/epoch - 1ms/step
# Epoch 7/100
# 42/42 - 0s - loss: 0.0321 - 48ms/epoch - 1ms/step
# Epoch 8/100
# 42/42 - 0s - loss: 0.0285 - 48ms/epoch - 1ms/step
# Epoch 9/100
# 42/42 - 0s - loss: 0.0254 - 42ms/epoch - 1ms/step
# Epoch 10/100
# 42/42 - 0s - loss: 0.0228 - 47ms/epoch - 1ms/step
# Epoch 11/100
# 42/42 - 0s - loss: 0.0201 - 48ms/epoch - 1ms/step
# Epoch 12/100
# 42/42 - 0s - loss: 0.0183 - 45ms/epoch - 1ms/step
# Epoch 13/100
# 42/42 - 0s - loss: 0.0162 - 56ms/epoch - 1ms/step
# Epoch 14/100
# 42/42 - 0s - loss: 0.0148 - 44ms/epoch - 1ms/step
# Epoch 15/100
# 42/42 - 0s - loss: 0.0135 - 54ms/epoch - 1ms/step
# Epoch 16/100
# 42/42 - 0s - loss: 0.0126 - 47ms/epoch - 1ms/step
# Epoch 17/100
# 42/42 - 0s - loss: 0.0116 - 48ms/epoch - 1ms/step
# Epoch 18/100
# 42/42 - 0s - loss: 0.0111 - 50ms/epoch - 1ms/step
# Epoch 19/100
# 42/42 - 0s - loss: 0.0105 - 48ms/epoch - 1ms/step
# Epoch 20/100
# 42/42 - 0s - loss: 0.0103 - 50ms/epoch - 1ms/step
# Epoch 21/100
# 42/42 - 0s - loss: 0.0098 - 52ms/epoch - 1ms/step
# Epoch 22/100
# 42/42 - 0s - loss: 0.0097 - 53ms/epoch - 1ms/step
# Epoch 23/100
# 42/42 - 0s - loss: 0.0092 - 45ms/epoch - 1ms/step
# Epoch 24/100
# 42/42 - 0s - loss: 0.0094 - 46ms/epoch - 1ms/step
# Epoch 25/100
# 42/42 - 0s - loss: 0.0091 - 62ms/epoch - 1ms/step
# Epoch 26/100
# 42/42 - 0s - loss: 0.0090 - 51ms/epoch - 1ms/step
# Epoch 27/100
# 42/42 - 0s - loss: 0.0086 - 46ms/epoch - 1ms/step
# Epoch 28/100
# 42/42 - 0s - loss: 0.0085 - 46ms/epoch - 1ms/step
# Epoch 29/100
# 42/42 - 0s - loss: 0.0083 - 72ms/epoch - 2ms/step
# Epoch 30/100
# 42/42 - 0s - loss: 0.0083 - 50ms/epoch - 1ms/step
# Epoch 31/100
# 42/42 - 0s - loss: 0.0080 - 47ms/epoch - 1ms/step
# Epoch 32/100
# 42/42 - 0s - loss: 0.0078 - 48ms/epoch - 1ms/step
# Epoch 33/100
# 42/42 - 0s - loss: 0.0078 - 47ms/epoch - 1ms/step
# Epoch 34/100
# 42/42 - 0s - loss: 0.0077 - 49ms/epoch - 1ms/step
# Epoch 35/100
# 42/42 - 0s - loss: 0.0077 - 50ms/epoch - 1ms/step
# Epoch 36/100
# 42/42 - 0s - loss: 0.0074 - 46ms/epoch - 1ms/step
# Epoch 37/100
# 42/42 - 0s - loss: 0.0075 - 51ms/epoch - 1ms/step
# Epoch 38/100
# 42/42 - 0s - loss: 0.0073 - 47ms/epoch - 1ms/step
# Epoch 39/100
# 42/42 - 0s - loss: 0.0072 - 49ms/epoch - 1ms/step
# Epoch 40/100
# 42/42 - 0s - loss: 0.0070 - 46ms/epoch - 1ms/step
# Epoch 41/100
# 42/42 - 0s - loss: 0.0070 - 47ms/epoch - 1ms/step
# Epoch 42/100
# 42/42 - 0s - loss: 0.0070 - 49ms/epoch - 1ms/step
# Epoch 43/100
# 42/42 - 0s - loss: 0.0066 - 48ms/epoch - 1ms/step
# Epoch 44/100
# 42/42 - 0s - loss: 0.0067 - 50ms/epoch - 1ms/step
# Epoch 45/100
# 42/42 - 0s - loss: 0.0065 - 50ms/epoch - 1ms/step
# Epoch 46/100
# 42/42 - 0s - loss: 0.0065 - 48ms/epoch - 1ms/step
# Epoch 47/100
# 42/42 - 0s - loss: 0.0064 - 45ms/epoch - 1ms/step
# Epoch 48/100
# 42/42 - 0s - loss: 0.0063 - 44ms/epoch - 1ms/step
# Epoch 49/100
# 42/42 - 0s - loss: 0.0061 - 51ms/epoch - 1ms/step
# Epoch 50/100
# 42/42 - 0s - loss: 0.0063 - 48ms/epoch - 1ms/step
# Epoch 51/100
# 42/42 - 0s - loss: 0.0060 - 47ms/epoch - 1ms/step
# Epoch 52/100
# 42/42 - 0s - loss: 0.0061 - 47ms/epoch - 1ms/step
# Epoch 53/100
# 42/42 - 0s - loss: 0.0059 - 46ms/epoch - 1ms/step
# Epoch 54/100
# 42/42 - 0s - loss: 0.0059 - 45ms/epoch - 1ms/step
# Epoch 55/100
# 42/42 - 0s - loss: 0.0057 - 41ms/epoch - 967us/step
# Epoch 56/100
# 42/42 - 0s - loss: 0.0057 - 43ms/epoch - 1ms/step
# Epoch 57/100
# 42/42 - 0s - loss: 0.0056 - 47ms/epoch - 1ms/step
# Epoch 58/100
# 42/42 - 0s - loss: 0.0059 - 41ms/epoch - 975us/step
# Epoch 59/100
# 42/42 - 0s - loss: 0.0058 - 41ms/epoch - 974us/step
# Epoch 60/100
# 42/42 - 0s - loss: 0.0054 - 42ms/epoch - 1ms/step
# Epoch 61/100
# 42/42 - 0s - loss: 0.0053 - 41ms/epoch - 987us/step
# Epoch 62/100
# 42/42 - 0s - loss: 0.0053 - 43ms/epoch - 1ms/step
# Epoch 63/100
# 42/42 - 0s - loss: 0.0054 - 41ms/epoch - 981us/step
# Epoch 64/100
# 42/42 - 0s - loss: 0.0054 - 59ms/epoch - 1ms/step
# Epoch 65/100
# 42/42 - 0s - loss: 0.0054 - 44ms/epoch - 1ms/step
# Epoch 66/100
# 42/42 - 0s - loss: 0.0051 - 44ms/epoch - 1ms/step
# Epoch 67/100
# 42/42 - 0s - loss: 0.0050 - 46ms/epoch - 1ms/step
# Epoch 68/100
# 42/42 - 0s - loss: 0.0050 - 43ms/epoch - 1ms/step
# Epoch 69/100
# 42/42 - 0s - loss: 0.0050 - 42ms/epoch - 1ms/step
# Epoch 70/100
# 42/42 - 0s - loss: 0.0050 - 39ms/epoch - 940us/step
# Epoch 71/100
# 42/42 - 0s - loss: 0.0051 - 44ms/epoch - 1ms/step
# Epoch 72/100
# 42/42 - 0s - loss: 0.0049 - 43ms/epoch - 1ms/step
# Epoch 73/100
# 42/42 - 0s - loss: 0.0049 - 46ms/epoch - 1ms/step
# Epoch 74/100
# 42/42 - 0s - loss: 0.0047 - 69ms/epoch - 2ms/step
# Epoch 75/100
# 42/42 - 0s - loss: 0.0047 - 49ms/epoch - 1ms/step
# Epoch 76/100
# 42/42 - 0s - loss: 0.0047 - 42ms/epoch - 999us/step
# Epoch 77/100
# 42/42 - 0s - loss: 0.0046 - 42ms/epoch - 994us/step
# Epoch 78/100
# 42/42 - 0s - loss: 0.0046 - 39ms/epoch - 936us/step
# Epoch 79/100
# 42/42 - 0s - loss: 0.0045 - 44ms/epoch - 1ms/step
# Epoch 80/100
# 42/42 - 0s - loss: 0.0046 - 51ms/epoch - 1ms/step
# Epoch 81/100
# 42/42 - 0s - loss: 0.0045 - 44ms/epoch - 1ms/step
# Epoch 82/100
# 42/42 - 0s - loss: 0.0045 - 43ms/epoch - 1ms/step
# Epoch 83/100
# 42/42 - 0s - loss: 0.0044 - 44ms/epoch - 1ms/step
# Epoch 84/100
# 42/42 - 0s - loss: 0.0045 - 40ms/epoch - 960us/step
# Epoch 85/100
# 42/42 - 0s - loss: 0.0043 - 43ms/epoch - 1ms/step
# Epoch 86/100
# 42/42 - 0s - loss: 0.0044 - 46ms/epoch - 1ms/step
# Epoch 87/100
# 42/42 - 0s - loss: 0.0045 - 43ms/epoch - 1ms/step
# Epoch 88/100
# 42/42 - 0s - loss: 0.0042 - 43ms/epoch - 1ms/step
# Epoch 89/100
# 42/42 - 0s - loss: 0.0043 - 42ms/epoch - 1ms/step
# Epoch 90/100
# 42/42 - 0s - loss: 0.0042 - 41ms/epoch - 975us/step
# Epoch 91/100
# 42/42 - 0s - loss: 0.0044 - 46ms/epoch - 1ms/step
# Epoch 92/100
# 42/42 - 0s - loss: 0.0042 - 46ms/epoch - 1ms/step
# Epoch 93/100
# 42/42 - 0s - loss: 0.0044 - 51ms/epoch - 1ms/step
# Epoch 94/100
# 42/42 - 0s - loss: 0.0040 - 46ms/epoch - 1ms/step
# Epoch 95/100
# 42/42 - 0s - loss: 0.0042 - 44ms/epoch - 1ms/step
# Epoch 96/100
# 42/42 - 0s - loss: 0.0040 - 44ms/epoch - 1ms/step
# Epoch 97/100
# 42/42 - 0s - loss: 0.0041 - 42ms/epoch - 994us/step
# Epoch 98/100
# 42/42 - 0s - loss: 0.0041 - 48ms/epoch - 1ms/step
# Epoch 99/100
# 42/42 - 0s - loss: 0.0040 - 43ms/epoch - 1ms/step
# Epoch 100/100
# 42/42 - 0s - loss: 0.0039 - 45ms/epoch - 1ms/step
# 14
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# Next values:  [15.613069, 15.619561, 15.413656, 15.813671, 17.037651, 17.882818, 18.7215, 18.960178, 19.279327, 19.395382, 36.893707, 33.84757, 36.148754, 37.31583]
# Test Score: 8.81 RMSE

# %% [markdown]
# ### Monthly basis

# %%
model_LSTM(pre_LSTM(data1M), 1)
# Out:
# Epoch 1/100
# 11/11 - 1s - loss: 0.1003 - 1s/epoch - 127ms/step
# Epoch 2/100
# 11/11 - 0s - loss: 0.0951 - 18ms/epoch - 2ms/step
# Epoch 3/100
# 11/11 - 0s - loss: 0.0902 - 32ms/epoch - 3ms/step
# Epoch 4/100
# 11/11 - 0s - loss: 0.0855 - 33ms/epoch - 3ms/step
# Epoch 5/100
# 11/11 - 0s - loss: 0.0820 - 45ms/epoch - 4ms/step
# Epoch 6/100
# 11/11 - 0s - loss: 0.0785 - 22ms/epoch - 2ms/step
# Epoch 7/100
# 11/11 - 0s - loss: 0.0746 - 21ms/epoch - 2ms/step
# Epoch 8/100
# 11/11 - 0s - loss: 0.0719 - 18ms/epoch - 2ms/step
# Epoch 9/100
# 11/11 - 0s - loss: 0.0692 - 17ms/epoch - 2ms/step
# Epoch 10/100
# 11/11 - 0s - loss: 0.0665 - 16ms/epoch - 1ms/step
# Epoch 11/100
# 11/11 - 0s - loss: 0.0648 - 19ms/epoch - 2ms/step
# Epoch 12/100
# 11/11 - 0s - loss: 0.0632 - 17ms/epoch - 2ms/step
# Epoch 13/100
# 11/11 - 0s - loss: 0.0613 - 20ms/epoch - 2ms/step
# Epoch 14/100
# 11/11 - 0s - loss: 0.0594 - 17ms/epoch - 2ms/step
# Epoch 15/100
# 11/11 - 0s - loss: 0.0582 - 17ms/epoch - 2ms/step
# Epoch 16/100
# 11/11 - 0s - loss: 0.0569 - 19ms/epoch - 2ms/step
# Epoch 17/100
# 11/11 - 0s - loss: 0.0560 - 17ms/epoch - 2ms/step
# Epoch 18/100
# 11/11 - 0s - loss: 0.0550 - 18ms/epoch - 2ms/step
# Epoch 19/100
# 11/11 - 0s - loss: 0.0547 - 18ms/epoch - 2ms/step
# Epoch 20/100
# 11/11 - 0s - loss: 0.0535 - 17ms/epoch - 2ms/step
# Epoch 21/100
# 11/11 - 0s - loss: 0.0529 - 18ms/epoch - 2ms/step
# Epoch 22/100
# 11/11 - 0s - loss: 0.0525 - 17ms/epoch - 2ms/step
# Epoch 23/100
# 11/11 - 0s - loss: 0.0524 - 18ms/epoch - 2ms/step
# Epoch 24/100
# 11/11 - 0s - loss: 0.0517 - 19ms/epoch - 2ms/step
# Epoch 25/100
# 11/11 - 0s - loss: 0.0514 - 17ms/epoch - 2ms/step
# Epoch 26/100
# 11/11 - 0s - loss: 0.0510 - 16ms/epoch - 1ms/step
# Epoch 27/100
# 11/11 - 0s - loss: 0.0508 - 17ms/epoch - 2ms/step
# Epoch 28/100
# 11/11 - 0s - loss: 0.0506 - 16ms/epoch - 1ms/step
# Epoch 29/100
# 11/11 - 0s - loss: 0.0503 - 15ms/epoch - 1ms/step
# Epoch 30/100
# 11/11 - 0s - loss: 0.0502 - 15ms/epoch - 1ms/step
# Epoch 31/100
# 11/11 - 0s - loss: 0.0501 - 16ms/epoch - 1ms/step
# Epoch 32/100
# 11/11 - 0s - loss: 0.0499 - 15ms/epoch - 1ms/step
# Epoch 33/100
# 11/11 - 0s - loss: 0.0498 - 15ms/epoch - 1ms/step
# Epoch 34/100
# 11/11 - 0s - loss: 0.0497 - 17ms/epoch - 2ms/step
# Epoch 35/100
# 11/11 - 0s - loss: 0.0496 - 19ms/epoch - 2ms/step
# Epoch 36/100
# 11/11 - 0s - loss: 0.0495 - 16ms/epoch - 1ms/step
# Epoch 37/100
# 11/11 - 0s - loss: 0.0493 - 15ms/epoch - 1ms/step
# Epoch 38/100
# 11/11 - 0s - loss: 0.0493 - 15ms/epoch - 1ms/step
# Epoch 39/100
# 11/11 - 0s - loss: 0.0493 - 15ms/epoch - 1ms/step
# Epoch 40/100
# 11/11 - 0s - loss: 0.0496 - 16ms/epoch - 1ms/step
# Epoch 41/100
# 11/11 - 0s - loss: 0.0491 - 15ms/epoch - 1ms/step
# Epoch 42/100
# 11/11 - 0s - loss: 0.0490 - 15ms/epoch - 1ms/step
# Epoch 43/100
# 11/11 - 0s - loss: 0.0491 - 16ms/epoch - 1ms/step
# Epoch 44/100
# 11/11 - 0s - loss: 0.0489 - 16ms/epoch - 1ms/step
# Epoch 45/100
# 11/11 - 0s - loss: 0.0491 - 15ms/epoch - 1ms/step
# Epoch 46/100
# 11/11 - 0s - loss: 0.0489 - 15ms/epoch - 1ms/step
# Epoch 47/100
# 11/11 - 0s - loss: 0.0488 - 16ms/epoch - 1ms/step
# Epoch 48/100
# 11/11 - 0s - loss: 0.0487 - 16ms/epoch - 1ms/step
# Epoch 49/100
# 11/11 - 0s - loss: 0.0486 - 16ms/epoch - 1ms/step
# Epoch 50/100
# 11/11 - 0s - loss: 0.0488 - 16ms/epoch - 1ms/step
# Epoch 51/100
# 11/11 - 0s - loss: 0.0486 - 17ms/epoch - 2ms/step
# Epoch 52/100
# 11/11 - 0s - loss: 0.0486 - 18ms/epoch - 2ms/step
# Epoch 53/100
# 11/11 - 0s - loss: 0.0484 - 17ms/epoch - 2ms/step
# Epoch 54/100
# 11/11 - 0s - loss: 0.0484 - 16ms/epoch - 1ms/step
# Epoch 55/100
# 11/11 - 0s - loss: 0.0483 - 17ms/epoch - 2ms/step
# Epoch 56/100
# 11/11 - 0s - loss: 0.0483 - 14ms/epoch - 1ms/step
# Epoch 57/100
# 11/11 - 0s - loss: 0.0483 - 13ms/epoch - 1ms/step
# Epoch 58/100
# 11/11 - 0s - loss: 0.0482 - 18ms/epoch - 2ms/step
# Epoch 59/100
# 11/11 - 0s - loss: 0.0482 - 16ms/epoch - 1ms/step
# Epoch 60/100
# 11/11 - 0s - loss: 0.0482 - 14ms/epoch - 1ms/step
# Epoch 61/100
# 11/11 - 0s - loss: 0.0481 - 12ms/epoch - 1ms/step
# Epoch 62/100
# 11/11 - 0s - loss: 0.0482 - 17ms/epoch - 2ms/step
# Epoch 63/100
# 11/11 - 0s - loss: 0.0481 - 17ms/epoch - 2ms/step
# Epoch 64/100
# 11/11 - 0s - loss: 0.0480 - 13ms/epoch - 1ms/step
# Epoch 65/100
# 11/11 - 0s - loss: 0.0483 - 14ms/epoch - 1ms/step
# Epoch 66/100
# 11/11 - 0s - loss: 0.0479 - 14ms/epoch - 1ms/step
# Epoch 67/100
# 11/11 - 0s - loss: 0.0480 - 15ms/epoch - 1ms/step
# Epoch 68/100
# 11/11 - 0s - loss: 0.0478 - 14ms/epoch - 1ms/step
# Epoch 69/100
# 11/11 - 0s - loss: 0.0479 - 14ms/epoch - 1ms/step
# Epoch 70/100
# 11/11 - 0s - loss: 0.0479 - 15ms/epoch - 1ms/step
# Epoch 71/100
# 11/11 - 0s - loss: 0.0477 - 15ms/epoch - 1ms/step
# Epoch 72/100
# 11/11 - 0s - loss: 0.0479 - 14ms/epoch - 1ms/step
# Epoch 73/100
# 11/11 - 0s - loss: 0.0476 - 13ms/epoch - 1ms/step
# Epoch 74/100
# 11/11 - 0s - loss: 0.0476 - 14ms/epoch - 1ms/step
# Epoch 75/100
# 11/11 - 0s - loss: 0.0476 - 15ms/epoch - 1ms/step
# Epoch 76/100
# 11/11 - 0s - loss: 0.0475 - 15ms/epoch - 1ms/step
# Epoch 77/100
# 11/11 - 0s - loss: 0.0476 - 15ms/epoch - 1ms/step
# Epoch 78/100
# 11/11 - 0s - loss: 0.0477 - 16ms/epoch - 1ms/step
# Epoch 79/100
# 11/11 - 0s - loss: 0.0475 - 13ms/epoch - 1ms/step
# Epoch 80/100
# 11/11 - 0s - loss: 0.0475 - 12ms/epoch - 1ms/step
# Epoch 81/100
# 11/11 - 0s - loss: 0.0474 - 13ms/epoch - 1ms/step
# Epoch 82/100
# 11/11 - 0s - loss: 0.0474 - 13ms/epoch - 1ms/step
# Epoch 83/100
# 11/11 - 0s - loss: 0.0475 - 14ms/epoch - 1ms/step
# Epoch 84/100
# 11/11 - 0s - loss: 0.0478 - 15ms/epoch - 1ms/step
# Epoch 85/100
# 11/11 - 0s - loss: 0.0472 - 16ms/epoch - 1ms/step
# Epoch 86/100
# 11/11 - 0s - loss: 0.0472 - 14ms/epoch - 1ms/step
# Epoch 87/100
# 11/11 - 0s - loss: 0.0472 - 15ms/epoch - 1ms/step
# Epoch 88/100
# 11/11 - 0s - loss: 0.0472 - 17ms/epoch - 2ms/step
# Epoch 89/100
# 11/11 - 0s - loss: 0.0472 - 19ms/epoch - 2ms/step
# Epoch 90/100
# 11/11 - 0s - loss: 0.0472 - 16ms/epoch - 1ms/step
# Epoch 91/100
# 11/11 - 0s - loss: 0.0473 - 15ms/epoch - 1ms/step
# Epoch 92/100
# 11/11 - 0s - loss: 0.0472 - 16ms/epoch - 1ms/step
# Epoch 93/100
# 11/11 - 0s - loss: 0.0471 - 15ms/epoch - 1ms/step
# Epoch 94/100
# 11/11 - 0s - loss: 0.0470 - 14ms/epoch - 1ms/step
# Epoch 95/100
# 11/11 - 0s - loss: 0.0471 - 13ms/epoch - 1ms/step
# Epoch 96/100
# 11/11 - 0s - loss: 0.0470 - 18ms/epoch - 2ms/step
# Epoch 97/100
# 11/11 - 0s - loss: 0.0469 - 14ms/epoch - 1ms/step
# Epoch 98/100
# 11/11 - 0s - loss: 0.0471 - 13ms/epoch - 1ms/step
# Epoch 99/100
# 11/11 - 0s - loss: 0.0469 - 12ms/epoch - 1ms/step
# Epoch 100/100
# 11/11 - 0s - loss: 0.0469 - 14ms/epoch - 1ms/step
# 3
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# Next values:  [16.826616, 19.115519, 19.132668]
# Test Score: 3.62 RMSE

# %%
model_LSTM(pre_LSTM(data1M), 3)
# Out:
# Epoch 1/100
# 9/9 - 1s - loss: 0.1049 - 1s/epoch - 147ms/step
# Epoch 2/100
# 9/9 - 0s - loss: 0.1000 - 19ms/epoch - 2ms/step
# Epoch 3/100
# 9/9 - 0s - loss: 0.0961 - 24ms/epoch - 3ms/step
# Epoch 4/100
# 9/9 - 0s - loss: 0.0910 - 22ms/epoch - 2ms/step
# Epoch 5/100
# 9/9 - 0s - loss: 0.0875 - 23ms/epoch - 3ms/step
# Epoch 6/100
# 9/9 - 0s - loss: 0.0842 - 22ms/epoch - 2ms/step
# Epoch 7/100
# 9/9 - 0s - loss: 0.0808 - 20ms/epoch - 2ms/step
# Epoch 8/100
# 9/9 - 0s - loss: 0.0783 - 27ms/epoch - 3ms/step
# Epoch 9/100
# 9/9 - 0s - loss: 0.0746 - 24ms/epoch - 3ms/step
# Epoch 10/100
# 9/9 - 0s - loss: 0.0722 - 24ms/epoch - 3ms/step
# Epoch 11/100
# 9/9 - 0s - loss: 0.0700 - 20ms/epoch - 2ms/step
# Epoch 12/100
# 9/9 - 0s - loss: 0.0671 - 16ms/epoch - 2ms/step
# Epoch 13/100
# 9/9 - 0s - loss: 0.0649 - 16ms/epoch - 2ms/step
# Epoch 14/100
# 9/9 - 0s - loss: 0.0627 - 18ms/epoch - 2ms/step
# Epoch 15/100
# 9/9 - 0s - loss: 0.0611 - 17ms/epoch - 2ms/step
# Epoch 16/100
# 9/9 - 0s - loss: 0.0588 - 15ms/epoch - 2ms/step
# Epoch 17/100
# 9/9 - 0s - loss: 0.0568 - 14ms/epoch - 2ms/step
# Epoch 18/100
# 9/9 - 0s - loss: 0.0549 - 16ms/epoch - 2ms/step
# Epoch 19/100
# 9/9 - 0s - loss: 0.0541 - 15ms/epoch - 2ms/step
# Epoch 20/100
# 9/9 - 0s - loss: 0.0516 - 14ms/epoch - 2ms/step
# Epoch 21/100
# 9/9 - 0s - loss: 0.0500 - 15ms/epoch - 2ms/step
# Epoch 22/100
# 9/9 - 0s - loss: 0.0487 - 15ms/epoch - 2ms/step
# Epoch 23/100
# 9/9 - 0s - loss: 0.0472 - 16ms/epoch - 2ms/step
# Epoch 24/100
# 9/9 - 0s - loss: 0.0456 - 16ms/epoch - 2ms/step
# Epoch 25/100
# 9/9 - 0s - loss: 0.0443 - 16ms/epoch - 2ms/step
# Epoch 26/100
# 9/9 - 0s - loss: 0.0429 - 15ms/epoch - 2ms/step
# Epoch 27/100
# 9/9 - 0s - loss: 0.0417 - 16ms/epoch - 2ms/step
# Epoch 28/100
# 9/9 - 0s - loss: 0.0406 - 18ms/epoch - 2ms/step
# Epoch 29/100
# 9/9 - 0s - loss: 0.0395 - 19ms/epoch - 2ms/step
# Epoch 30/100
# 9/9 - 0s - loss: 0.0382 - 16ms/epoch - 2ms/step
# Epoch 31/100
# 9/9 - 0s - loss: 0.0371 - 16ms/epoch - 2ms/step
# Epoch 32/100
# 9/9 - 0s - loss: 0.0360 - 15ms/epoch - 2ms/step
# Epoch 33/100
# 9/9 - 0s - loss: 0.0348 - 13ms/epoch - 1ms/step
# Epoch 34/100
# 9/9 - 0s - loss: 0.0340 - 15ms/epoch - 2ms/step
# Epoch 35/100
# 9/9 - 0s - loss: 0.0330 - 13ms/epoch - 1ms/step
# Epoch 36/100
# 9/9 - 0s - loss: 0.0323 - 14ms/epoch - 2ms/step
# Epoch 37/100
# 9/9 - 0s - loss: 0.0313 - 12ms/epoch - 1ms/step
# Epoch 38/100
# 9/9 - 0s - loss: 0.0305 - 15ms/epoch - 2ms/step
# Epoch 39/100
# 9/9 - 0s - loss: 0.0297 - 15ms/epoch - 2ms/step
# Epoch 40/100
# 9/9 - 0s - loss: 0.0290 - 16ms/epoch - 2ms/step
# Epoch 41/100
# 9/9 - 0s - loss: 0.0286 - 17ms/epoch - 2ms/step
# Epoch 42/100
# 9/9 - 0s - loss: 0.0277 - 18ms/epoch - 2ms/step
# Epoch 43/100
# 9/9 - 0s - loss: 0.0268 - 18ms/epoch - 2ms/step
# Epoch 44/100
# 9/9 - 0s - loss: 0.0264 - 16ms/epoch - 2ms/step
# Epoch 45/100
# 9/9 - 0s - loss: 0.0257 - 17ms/epoch - 2ms/step
# Epoch 46/100
# 9/9 - 0s - loss: 0.0252 - 15ms/epoch - 2ms/step
# Epoch 47/100
# 9/9 - 0s - loss: 0.0248 - 16ms/epoch - 2ms/step
# Epoch 48/100
# 9/9 - 0s - loss: 0.0242 - 16ms/epoch - 2ms/step
# Epoch 49/100
# 9/9 - 0s - loss: 0.0237 - 17ms/epoch - 2ms/step
# Epoch 50/100
# 9/9 - 0s - loss: 0.0233 - 16ms/epoch - 2ms/step
# Epoch 51/100
# 9/9 - 0s - loss: 0.0231 - 15ms/epoch - 2ms/step
# Epoch 52/100
# 9/9 - 0s - loss: 0.0225 - 15ms/epoch - 2ms/step
# Epoch 53/100
# 9/9 - 0s - loss: 0.0222 - 15ms/epoch - 2ms/step
# Epoch 54/100
# 9/9 - 0s - loss: 0.0217 - 13ms/epoch - 1ms/step
# Epoch 55/100
# 9/9 - 0s - loss: 0.0214 - 18ms/epoch - 2ms/step
# Epoch 56/100
# 9/9 - 0s - loss: 0.0212 - 13ms/epoch - 1ms/step
# Epoch 57/100
# 9/9 - 0s - loss: 0.0209 - 12ms/epoch - 1ms/step
# Epoch 58/100
# 9/9 - 0s - loss: 0.0207 - 13ms/epoch - 1ms/step
# Epoch 59/100
# 9/9 - 0s - loss: 0.0205 - 20ms/epoch - 2ms/step
# Epoch 60/100
# 9/9 - 0s - loss: 0.0201 - 20ms/epoch - 2ms/step
# Epoch 61/100
# 9/9 - 0s - loss: 0.0199 - 17ms/epoch - 2ms/step
# Epoch 62/100
# 9/9 - 0s - loss: 0.0196 - 15ms/epoch - 2ms/step
# Epoch 63/100
# 9/9 - 0s - loss: 0.0194 - 14ms/epoch - 2ms/step
# Epoch 64/100
# 9/9 - 0s - loss: 0.0193 - 11ms/epoch - 1ms/step
# Epoch 65/100
# 9/9 - 0s - loss: 0.0192 - 14ms/epoch - 2ms/step
# Epoch 66/100
# 9/9 - 0s - loss: 0.0193 - 15ms/epoch - 2ms/step
# Epoch 67/100
# 9/9 - 0s - loss: 0.0187 - 12ms/epoch - 1ms/step
# Epoch 68/100
# 9/9 - 0s - loss: 0.0187 - 12ms/epoch - 1ms/step
# Epoch 69/100
# 9/9 - 0s - loss: 0.0184 - 11ms/epoch - 1ms/step
# Epoch 70/100
# 9/9 - 0s - loss: 0.0183 - 12ms/epoch - 1ms/step
# Epoch 71/100
# 9/9 - 0s - loss: 0.0182 - 11ms/epoch - 1ms/step
# Epoch 72/100
# 9/9 - 0s - loss: 0.0179 - 10ms/epoch - 1ms/step
# Epoch 73/100
# 9/9 - 0s - loss: 0.0179 - 11ms/epoch - 1ms/step
# Epoch 74/100
# 9/9 - 0s - loss: 0.0179 - 13ms/epoch - 1ms/step
# Epoch 75/100
# 9/9 - 0s - loss: 0.0176 - 14ms/epoch - 2ms/step
# Epoch 76/100
# 9/9 - 0s - loss: 0.0175 - 11ms/epoch - 1ms/step
# Epoch 77/100
# 9/9 - 0s - loss: 0.0174 - 11ms/epoch - 1ms/step
# Epoch 78/100
# 9/9 - 0s - loss: 0.0172 - 12ms/epoch - 1ms/step
# Epoch 79/100
# 9/9 - 0s - loss: 0.0172 - 11ms/epoch - 1ms/step
# Epoch 80/100
# 9/9 - 0s - loss: 0.0171 - 11ms/epoch - 1ms/step
# Epoch 81/100
# 9/9 - 0s - loss: 0.0170 - 11ms/epoch - 1ms/step
# Epoch 82/100
# 9/9 - 0s - loss: 0.0168 - 13ms/epoch - 1ms/step
# Epoch 83/100
# 9/9 - 0s - loss: 0.0167 - 12ms/epoch - 1ms/step
# Epoch 84/100
# 9/9 - 0s - loss: 0.0166 - 12ms/epoch - 1ms/step
# Epoch 85/100
# 9/9 - 0s - loss: 0.0165 - 12ms/epoch - 1ms/step
# Epoch 86/100
# 9/9 - 0s - loss: 0.0164 - 14ms/epoch - 2ms/step
# Epoch 87/100
# 9/9 - 0s - loss: 0.0164 - 38ms/epoch - 4ms/step
# Epoch 88/100
# 9/9 - 0s - loss: 0.0162 - 14ms/epoch - 2ms/step
# Epoch 89/100
# 9/9 - 0s - loss: 0.0162 - 13ms/epoch - 1ms/step
# Epoch 90/100
# 9/9 - 0s - loss: 0.0160 - 11ms/epoch - 1ms/step
# Epoch 91/100
# 9/9 - 0s - loss: 0.0160 - 12ms/epoch - 1ms/step
# Epoch 92/100
# 9/9 - 0s - loss: 0.0159 - 14ms/epoch - 2ms/step
# Epoch 93/100
# 9/9 - 0s - loss: 0.0158 - 14ms/epoch - 2ms/step
# Epoch 94/100
# 9/9 - 0s - loss: 0.0157 - 14ms/epoch - 2ms/step
# Epoch 95/100
# 9/9 - 0s - loss: 0.0156 - 12ms/epoch - 1ms/step
# Epoch 96/100
# 9/9 - 0s - loss: 0.0157 - 13ms/epoch - 1ms/step
# Epoch 97/100
# 9/9 - 0s - loss: 0.0155 - 12ms/epoch - 1ms/step
# Epoch 98/100
# 9/9 - 0s - loss: 0.0154 - 12ms/epoch - 1ms/step
# Epoch 99/100
# 9/9 - 0s - loss: 0.0153 - 15ms/epoch - 2ms/step
# Epoch 100/100
# 9/9 - 0s - loss: 0.0152 - 13ms/epoch - 1ms/step
# 3
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# Next values:  [15.870376, 16.967157, 17.751549]
# Test Score: 5.04 RMSE

# %% [markdown]
# Multi-Step LSTM Models?
#
#
# Vector Output Model?
# Encoder-Decoder Model?

# %% [markdown]
# ## Auto-ARIMA model

# %%
from pmdarima import auto_arima

# %%
def auto_ARIMA(dataframe):
    # split into train and test sets
    train = dataframe[:int(0.8*(len(dataframe)))]
    valid = dataframe[int(0.8*(len(dataframe))):]
   
    model = auto_arima(train, trace=True, error_action='ignore', suppress_warnings=True)
    model.fit(train)

    forecast = model.predict(n_periods=len(valid))
    forecast = pd.DataFrame(forecast,index = valid.index,columns=['Prediction'])

    #plot the predictions for validation set
    plt.plot(train, label='Train', color = 'b')
    plt.plot(valid, label='Valid', color = 'g')
    plt.plot(forecast, label='Prediction', color = 'r')
    plt.show()

# %%
auto_ARIMA(data1['Price'])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=259.857, Time=0.53 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=254.949, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=256.283, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=256.238, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=252.963, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=257.994, Time=0.15 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.891 seconds

# %%
auto_ARIMA(data1W['Price'])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=232.487, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=134.168, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=443.820, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=127.526, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=129.387, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=129.263, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=127.398, Time=0.04 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=129.362, Time=0.08 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=159.177, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=132.330, Time=0.04 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 0.615 seconds

# %%
auto_ARIMA(data1M['Price'])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=55.233, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=54.049, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=103.956, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=46.214, Time=0.06 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=47.966, Time=0.10 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=48.028, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=49.971, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 0.667 seconds

# %% [markdown]
# ## Prophet model

# %%
def model_prophet(df):
    
    # Prepare the data for Prophet
    df = df.rename(columns={'Price': 'y'})
    df = df.reset_index().rename(columns={'Date': 'ds'})
    
    # split into train and test sets
    train = df[:int(0.8*(len(df)))]
    test = df[int(0.8*(len(df))):]

    # Create a Prophet model and fit it to the data
    model = Prophet()
    model.fit(train)

    # Make predictions for the next 365 days
    future = model.make_future_dataframe(periods=len(test))
    forecast = model.predict(future)

    # Plot the forecast
    model.plot(forecast)

# %%
model_prophet(data1)
# Out:
# 19:05:35 - cmdstanpy - INFO - Chain [1] start processing
# 19:05:35 - cmdstanpy - INFO - Chain [1] done processing

# %%
model_prophet(data1W)
# Out:
# 19:06:03 - cmdstanpy - INFO - Chain [1] start processing
# 19:06:03 - cmdstanpy - INFO - Chain [1] done processing

# %%
model_prophet(data1M)
# Out:
# 19:06:14 - cmdstanpy - INFO - Chain [1] start processing
# 19:06:14 - cmdstanpy - INFO - Chain [1] done processing
